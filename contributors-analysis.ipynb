# %% [markdown]
# # Out-of-State-Contributions: Contributors Analysis
#
# How much out-of-state money are contributors donating in the 2018 election cycle thus far and how does that compare with this point in the 2014 and 2010 cycles?

# %%
import numpy as np
import pandas as pd

pd.set_option("display.max_columns", 100)
pd.set_option("display.max_rows", 500)
pd.options.display.float_format = "{:,.2f}".format # Format floats

# %% [markdown]
# Import contributions data.

# %%
contributions = pd.read_csv("data/contributions.csv")
contributions.info()
# Out:
# /home/jyerardi/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (14,17,18,19,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6947770 entries, 0 to 6947769
# Data columns (total 23 columns):
# candidate                 object
# candidate_id              int64
# year                      int64
# state                     object
# party                     object
# election_status           object
# contributor               object
# amount                    float64
# date                      object
# contributor_street        object
# contributor_city          object
# contributor_state         object
# contributor_zip           float64
# in_out_state              object
# no_veto                   object
# office                    object
# last_day                  object
# redistricting_role        object
# independent_commission    object
# single_house_district     object
# standardized_office       object
# standardized_status       object
# two_year_term             object
# dtypes: float64(2), int64(2), object(19)
# memory usage: 1.2+ GB

# %% [markdown]
# Convert the contribution date and last day columns to datetime data type.

# %%
contributions["date"] = pd.to_datetime(contributions["date"], errors="coerce")
contributions["last_day"] = pd.to_datetime(contributions["last_day"], errors="coerce")
contributions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6947770 entries, 0 to 6947769
# Data columns (total 23 columns):
# candidate                 object
# candidate_id              int64
# year                      int64
# state                     object
# party                     object
# election_status           object
# contributor               object
# amount                    float64
# date                      datetime64[ns]
# contributor_street        object
# contributor_city          object
# contributor_state         object
# contributor_zip           float64
# in_out_state              object
# no_veto                   object
# office                    object
# last_day                  datetime64[ns]
# redistricting_role        object
# independent_commission    object
# single_house_district     object
# standardized_office       object
# standardized_status       object
# two_year_term             object
# dtypes: datetime64[ns](2), float64(2), int64(2), object(17)
# memory usage: 1.2+ GB

# %% [markdown]
# ## Is there a difference in the average out-of-state contribution to Democratic vs. Republican candidates?

# %% [markdown]
# Group by year, party, office and in-vs.-out-of-state contribution status and calculate the total contributions, average contributions, median contributions and number of contributions per group.

# %%
contributions_by_party_office = contributions.groupby(["year", "party", "standardized_office", "in_out_state"])["amount"].agg([sum, np.average, "median", len]).reset_index()
contributions_by_party_office
# Out:
#     year        party           standardized_office  in_out_state  \
# 0   2010   Democratic  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 1   2010   Democratic  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 2   2010   Democratic  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 3   2010   Democratic   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 4   2010   Democratic   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 5   2010   Democratic   STATE HOUSE/ASSEMBLY/SENATE       unknown
# 6   2010  Nonpartisan   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 7   2010  Nonpartisan   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 8   2010  Nonpartisan   STATE HOUSE/ASSEMBLY/SENATE       unknown
# 9   2010   Republican  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 10  2010   Republican  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 11  2010   Republican  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 12  2010   Republican   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 13  2010   Republican   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 14  2010   Republican   STATE HOUSE/ASSEMBLY/SENATE       unknown
# 15  2010  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 16  2010  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 17  2010  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 18  2010  Third-Party   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 19  2010  Third-Party   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 20  2010  Third-Party   STATE HOUSE/ASSEMBLY/SENATE       unknown
# 21  2014   Democratic  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 22  2014   Democratic  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 23  2014   Democratic  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 24  2014   Democratic   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 25  2014   Democratic   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 26  2014   Democratic   STATE HOUSE/ASSEMBLY/SENATE       unknown
# 27  2014  Nonpartisan   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 28  2014  Nonpartisan   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 29  2014  Nonpartisan   STATE HOUSE/ASSEMBLY/SENATE       unknown
# 30  2014   Republican  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 31  2014   Republican  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 32  2014   Republican  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 33  2014   Republican   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 34  2014   Republican   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 35  2014   Republican   STATE HOUSE/ASSEMBLY/SENATE       unknown
# 36  2014  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 37  2014  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 38  2014  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 39  2014  Third-Party   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 40  2014  Third-Party   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 41  2014  Third-Party   STATE HOUSE/ASSEMBLY/SENATE       unknown
# 42  2018   Democratic  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 43  2018   Democratic  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 44  2018   Democratic  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 45  2018   Democratic   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 46  2018   Democratic   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 47  2018   Democratic   STATE HOUSE/ASSEMBLY/SENATE       unknown
# 48  2018  Nonpartisan   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 49  2018  Nonpartisan   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 50  2018  Nonpartisan   STATE HOUSE/ASSEMBLY/SENATE       unknown
# 51  2018   Republican  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 52  2018   Republican  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 53  2018   Republican  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 54  2018   Republican   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 55  2018   Republican   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 56  2018   Republican   STATE HOUSE/ASSEMBLY/SENATE       unknown
# 57  2018  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 58  2018  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 59  2018  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 60  2018  Third-Party   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 61  2018  Third-Party   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 62  2018  Third-Party   STATE HOUSE/ASSEMBLY/SENATE       unknown
#
#               sum   average  median        len
# 0  249,405,839.52    816.77  100.00 305,356.00
# 1   35,779,114.12  1,071.46  250.00  33,393.00
# 2      369,604.83    378.69  100.00     976.00
# 3  272,893,234.09    414.35  100.00 658,609.00
# 4   28,680,059.56    494.21  250.00  58,032.00
# 5    1,342,191.95    340.49  100.00   3,942.00
# 6    1,001,559.24    463.47  300.00   2,161.00
# 7      143,053.70    529.83  500.00     270.00
# 8      -19,438.72 -1,295.91  -75.00      15.00
# 9  482,613,987.05  1,106.53  100.00 436,151.00
# 10  39,151,620.03  1,168.91  200.00  33,494.00
# 11     240,129.43    444.68   50.00     540.00
# 12 231,341,884.21    414.63  125.00 557,950.00
# 13  19,206,369.09    489.93  350.00  39,202.00
# 14     639,587.51    273.44  100.00   2,339.00
# 15   3,627,843.15    289.83  100.00  12,517.00
# 16     554,492.88    122.59   33.00   4,523.00
# 17   1,626,288.15 14,920.07  250.00     109.00
# 18   3,345,511.14    371.02  100.00   9,017.00
# 19     309,124.31    425.21  200.00     727.00
# 20       1,431.48     13.76   50.00     104.00
# 21 208,592,453.21    606.98   50.00 343,657.00
# 22  45,439,296.05    490.08   35.00  92,719.00
# 23   1,783,287.65    315.51  125.00   5,652.00
# 24 239,422,578.44    423.85  100.00 564,875.00
# 25  30,538,086.59    411.31  100.00  74,246.00
# 26   4,522,351.40    227.63  103.00  19,867.00
# 27   1,788,615.01    542.50  250.00   3,297.00
# 28     182,893.05    589.98  500.00     310.00
# 29       4,068.00    581.14  500.00       7.00
# 30 226,742,799.24    676.67  100.00 335,088.00
# 31  51,536,542.44    466.36   50.00 110,509.00
# 32   8,468,869.94  2,119.87   50.00   3,995.00
# 33 287,319,524.73    539.82  200.00 532,252.00
# 34  28,200,167.11    603.68  500.00  46,714.00
# 35   2,741,740.55    563.45  111.79   4,866.00
# 36   9,026,796.83  1,293.42  100.00   6,979.00
# 37     377,039.85    318.98  100.00   1,182.00
# 38      20,805.96    371.54    9.98      56.00
# 39   3,993,147.45    494.20  100.00   8,080.00
# 40     257,766.09    289.95  100.00     889.00
# 41      19,480.08    414.47  100.00      47.00
# 42 446,414,596.86    901.61   50.00 495,128.00
# 43  59,816,942.73    278.51   25.00 214,778.00
# 44   3,210,357.50  1,266.41   25.00   2,535.00
# 45 250,955,888.64    378.54  100.00 662,957.00
# 46  41,343,033.37    356.38  100.00 116,008.00
# 47   6,907,666.51    293.66  100.00  23,523.00
# 48   1,642,246.38    582.36  250.00   2,820.00
# 49     336,165.87    757.13  500.00     444.00
# 50      -2,307.58   -153.84  500.00      15.00
# 51 491,807,244.52  1,056.14   80.00 465,667.00
# 52  42,632,032.87    286.40   50.00 148,855.00
# 53   3,984,424.72  3,132.41  200.00   1,272.00
# 54 286,263,804.75    656.45  250.00 436,078.00
# 55  29,093,022.07    732.62  500.00  39,711.00
# 56   5,489,302.33    469.25  250.00  11,698.00
# 57   2,450,299.02    427.70  100.00   5,729.00
# 58     192,962.51    196.90  100.00     980.00
# 59     419,218.37  2,117.26   25.00     198.00
# 60     869,801.44    236.68   85.00   3,675.00
# 61     146,916.86    156.29   50.00     940.00
# 62      67,030.91  1,558.86  500.00      43.00

# %% [markdown]
# Drop non-major parties and unknown contribution statuses.

# %%
contributions_by_party_office = contributions_by_party_office[((contributions_by_party_office["party"] == "Democratic") | (contributions_by_party_office["party"] == "Republican")) & (contributions_by_party_office["in_out_state"] != "unknown")]
contributions_by_party_office
# Out:
#     year       party           standardized_office  in_out_state  \
# 0   2010  Democratic  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 1   2010  Democratic  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 3   2010  Democratic   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 4   2010  Democratic   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 9   2010  Republican  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 10  2010  Republican  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 12  2010  Republican   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 13  2010  Republican   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 21  2014  Democratic  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 22  2014  Democratic  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 24  2014  Democratic   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 25  2014  Democratic   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 30  2014  Republican  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 31  2014  Republican  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 33  2014  Republican   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 34  2014  Republican   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 42  2018  Democratic  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 43  2018  Democratic  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 45  2018  Democratic   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 46  2018  Democratic   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 51  2018  Republican  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 52  2018  Republican  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 54  2018  Republican   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 55  2018  Republican   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
#
#               sum  average  median        len
# 0  249,405,839.52   816.77  100.00 305,356.00
# 1   35,779,114.12 1,071.46  250.00  33,393.00
# 3  272,893,234.09   414.35  100.00 658,609.00
# 4   28,680,059.56   494.21  250.00  58,032.00
# 9  482,613,987.05 1,106.53  100.00 436,151.00
# 10  39,151,620.03 1,168.91  200.00  33,494.00
# 12 231,341,884.21   414.63  125.00 557,950.00
# 13  19,206,369.09   489.93  350.00  39,202.00
# 21 208,592,453.21   606.98   50.00 343,657.00
# 22  45,439,296.05   490.08   35.00  92,719.00
# 24 239,422,578.44   423.85  100.00 564,875.00
# 25  30,538,086.59   411.31  100.00  74,246.00
# 30 226,742,799.24   676.67  100.00 335,088.00
# 31  51,536,542.44   466.36   50.00 110,509.00
# 33 287,319,524.73   539.82  200.00 532,252.00
# 34  28,200,167.11   603.68  500.00  46,714.00
# 42 446,414,596.86   901.61   50.00 495,128.00
# 43  59,816,942.73   278.51   25.00 214,778.00
# 45 250,955,888.64   378.54  100.00 662,957.00
# 46  41,343,033.37   356.38  100.00 116,008.00
# 51 491,807,244.52 1,056.14   80.00 465,667.00
# 52  42,632,032.87   286.40   50.00 148,855.00
# 54 286,263,804.75   656.45  250.00 436,078.00
# 55  29,093,022.07   732.62  500.00  39,711.00

# %% [markdown]
# Pivot dataframe to aggregate each year and office's data in a single row.

# %%
contributions_by_party_office = pd.pivot_table(contributions_by_party_office, index=["year", "standardized_office"], columns=["party", "in_out_state"]).reset_index()
contributions_by_party_office
# Out:
#               year           standardized_office    average               \
# party                                            Democratic
# in_out_state                                       in-state out-of-state
# 0             2010  GOVERNOR/LIEUTENANT GOVERNOR     816.77     1,071.46
# 1             2010   STATE HOUSE/ASSEMBLY/SENATE     414.35       494.21
# 2             2014  GOVERNOR/LIEUTENANT GOVERNOR     606.98       490.08
# 3             2014   STATE HOUSE/ASSEMBLY/SENATE     423.85       411.31
# 4             2018  GOVERNOR/LIEUTENANT GOVERNOR     901.61       278.51
# 5             2018   STATE HOUSE/ASSEMBLY/SENATE     378.54       356.38
#
#                                             len                          \
# party        Republican              Democratic              Republican
# in_out_state   in-state out-of-state   in-state out-of-state   in-state
# 0              1,106.53     1,168.91 305,356.00    33,393.00 436,151.00
# 1                414.63       489.93 658,609.00    58,032.00 557,950.00
# 2                676.67       466.36 343,657.00    92,719.00 335,088.00
# 3                539.82       603.68 564,875.00    74,246.00 532,252.00
# 4              1,056.14       286.40 495,128.00   214,778.00 465,667.00
# 5                656.45       732.62 662,957.00   116,008.00 436,078.00
#
#                               median                                       \
# party                     Democratic              Republican
# in_out_state out-of-state   in-state out-of-state   in-state out-of-state
# 0               33,494.00     100.00       250.00     100.00       200.00
# 1               39,202.00     100.00       250.00     125.00       350.00
# 2              110,509.00      50.00        35.00     100.00        50.00
# 3               46,714.00     100.00       100.00     200.00       500.00
# 4              148,855.00      50.00        25.00      80.00        50.00
# 5               39,711.00     100.00       100.00     250.00       500.00
#
#                         sum
# party            Democratic                   Republican
# in_out_state       in-state  out-of-state       in-state  out-of-state
# 0            249,405,839.52 35,779,114.12 482,613,987.05 39,151,620.03
# 1            272,893,234.09 28,680,059.56 231,341,884.21 19,206,369.09
# 2            208,592,453.21 45,439,296.05 226,742,799.24 51,536,542.44
# 3            239,422,578.44 30,538,086.59 287,319,524.73 28,200,167.11
# 4            446,414,596.86 59,816,942.73 491,807,244.52 42,632,032.87
# 5            250,955,888.64 41,343,033.37 286,263,804.75 29,093,022.07

# %% [markdown]
# Flatten the resulting dataframe's multi-index columns.

# %%
contributions_by_party_office.columns = ["year", "standardized_office",
                                  "avg_dem_in_state", "avg_dem_out_of_state",
                                  "avg_rep_in_state", "avg_rep_out_of_state",
                                  "num_dem_in_state", "num_dem_out_of_state",
                                  "num_rep_in_state", "num_rep_out_of_state",
                                  "med_dem_in_state", "med_dem_out_of_state",
                                  "med_rep_in_state", "med_rep_out_of_state",
                                  "sum_dem_in_state", "sum_dem_out_of_state",
                                  "sum_rep_in_state", "sum_rep_out_of_state"
                                  ]                          
contributions_by_party_office
# Out:
#    year           standardized_office  avg_dem_in_state  avg_dem_out_of_state  \
# 0  2010  GOVERNOR/LIEUTENANT GOVERNOR            816.77              1,071.46
# 1  2010   STATE HOUSE/ASSEMBLY/SENATE            414.35                494.21
# 2  2014  GOVERNOR/LIEUTENANT GOVERNOR            606.98                490.08
# 3  2014   STATE HOUSE/ASSEMBLY/SENATE            423.85                411.31
# 4  2018  GOVERNOR/LIEUTENANT GOVERNOR            901.61                278.51
# 5  2018   STATE HOUSE/ASSEMBLY/SENATE            378.54                356.38
#
#    avg_rep_in_state  avg_rep_out_of_state  num_dem_in_state  \
# 0          1,106.53              1,168.91        305,356.00
# 1            414.63                489.93        658,609.00
# 2            676.67                466.36        343,657.00
# 3            539.82                603.68        564,875.00
# 4          1,056.14                286.40        495,128.00
# 5            656.45                732.62        662,957.00
#
#    num_dem_out_of_state  num_rep_in_state  num_rep_out_of_state  \
# 0             33,393.00        436,151.00             33,494.00
# 1             58,032.00        557,950.00             39,202.00
# 2             92,719.00        335,088.00            110,509.00
# 3             74,246.00        532,252.00             46,714.00
# 4            214,778.00        465,667.00            148,855.00
# 5            116,008.00        436,078.00             39,711.00
#
#    med_dem_in_state  med_dem_out_of_state  med_rep_in_state  \
# 0            100.00                250.00            100.00
# 1            100.00                250.00            125.00
# 2             50.00                 35.00            100.00
# 3            100.00                100.00            200.00
# 4             50.00                 25.00             80.00
# 5            100.00                100.00            250.00
#
#    med_rep_out_of_state  sum_dem_in_state  sum_dem_out_of_state  \
# 0                200.00    249,405,839.52         35,779,114.12
# 1                350.00    272,893,234.09         28,680,059.56
# 2                 50.00    208,592,453.21         45,439,296.05
# 3                500.00    239,422,578.44         30,538,086.59
# 4                 50.00    446,414,596.86         59,816,942.73
# 5                500.00    250,955,888.64         41,343,033.37
#
#    sum_rep_in_state  sum_rep_out_of_state
# 0    482,613,987.05         39,151,620.03
# 1    231,341,884.21         19,206,369.09
# 2    226,742,799.24         51,536,542.44
# 3    287,319,524.73         28,200,167.11
# 4    491,807,244.52         42,632,032.87
# 5    286,263,804.75         29,093,022.07

# %% [markdown]
# Calculate the difference between the parties.

# %%
contributions_by_party_office["diff_avg_in_state"] = (contributions_by_party_office["avg_rep_in_state"] - contributions_by_party_office["avg_dem_in_state"]) / contributions_by_party_office["avg_dem_in_state"]
contributions_by_party_office["diff_avg_out_of_state"] = (contributions_by_party_office["avg_rep_out_of_state"] - contributions_by_party_office["avg_dem_out_of_state"]) / contributions_by_party_office["avg_dem_out_of_state"]
contributions_by_party_office["diff_num_in_state"] = (contributions_by_party_office["num_rep_in_state"] - contributions_by_party_office["num_dem_in_state"]) / contributions_by_party_office["num_dem_in_state"]
contributions_by_party_office["diff_num_out_of_state"] = (contributions_by_party_office["num_rep_out_of_state"] - contributions_by_party_office["num_dem_out_of_state"]) / contributions_by_party_office["num_dem_out_of_state"]
contributions_by_party_office["diff_med_in_state"] = (contributions_by_party_office["med_rep_in_state"] - contributions_by_party_office["med_dem_in_state"]) / contributions_by_party_office["med_dem_in_state"]
contributions_by_party_office["diff_med_out_of_state"] = (contributions_by_party_office["med_rep_out_of_state"] - contributions_by_party_office["med_dem_out_of_state"]) / contributions_by_party_office["med_dem_out_of_state"]
contributions_by_party_office["diff_sum_in_state"] = (contributions_by_party_office["sum_rep_in_state"] - contributions_by_party_office["sum_dem_in_state"]) / contributions_by_party_office["sum_dem_in_state"]
contributions_by_party_office["diff_sum_out_of_state"] = (contributions_by_party_office["sum_rep_out_of_state"] - contributions_by_party_office["sum_dem_out_of_state"]) / contributions_by_party_office["sum_dem_out_of_state"]
contributions_by_party_office
# Out:
#    year           standardized_office  avg_dem_in_state  avg_dem_out_of_state  \
# 0  2010  GOVERNOR/LIEUTENANT GOVERNOR            816.77              1,071.46
# 1  2010   STATE HOUSE/ASSEMBLY/SENATE            414.35                494.21
# 2  2014  GOVERNOR/LIEUTENANT GOVERNOR            606.98                490.08
# 3  2014   STATE HOUSE/ASSEMBLY/SENATE            423.85                411.31
# 4  2018  GOVERNOR/LIEUTENANT GOVERNOR            901.61                278.51
# 5  2018   STATE HOUSE/ASSEMBLY/SENATE            378.54                356.38
#
#    avg_rep_in_state  avg_rep_out_of_state  num_dem_in_state  \
# 0          1,106.53              1,168.91        305,356.00
# 1            414.63                489.93        658,609.00
# 2            676.67                466.36        343,657.00
# 3            539.82                603.68        564,875.00
# 4          1,056.14                286.40        495,128.00
# 5            656.45                732.62        662,957.00
#
#    num_dem_out_of_state  num_rep_in_state  num_rep_out_of_state  \
# 0             33,393.00        436,151.00             33,494.00
# 1             58,032.00        557,950.00             39,202.00
# 2             92,719.00        335,088.00            110,509.00
# 3             74,246.00        532,252.00             46,714.00
# 4            214,778.00        465,667.00            148,855.00
# 5            116,008.00        436,078.00             39,711.00
#
#    med_dem_in_state  med_dem_out_of_state  med_rep_in_state  \
# 0            100.00                250.00            100.00
# 1            100.00                250.00            125.00
# 2             50.00                 35.00            100.00
# 3            100.00                100.00            200.00
# 4             50.00                 25.00             80.00
# 5            100.00                100.00            250.00
#
#    med_rep_out_of_state  sum_dem_in_state  sum_dem_out_of_state  \
# 0                200.00    249,405,839.52         35,779,114.12
# 1                350.00    272,893,234.09         28,680,059.56
# 2                 50.00    208,592,453.21         45,439,296.05
# 3                500.00    239,422,578.44         30,538,086.59
# 4                 50.00    446,414,596.86         59,816,942.73
# 5                500.00    250,955,888.64         41,343,033.37
#
#    sum_rep_in_state  sum_rep_out_of_state  diff_avg_in_state  \
# 0    482,613,987.05         39,151,620.03               0.35
# 1    231,341,884.21         19,206,369.09               0.00
# 2    226,742,799.24         51,536,542.44               0.11
# 3    287,319,524.73         28,200,167.11               0.27
# 4    491,807,244.52         42,632,032.87               0.17
# 5    286,263,804.75         29,093,022.07               0.73
#
#    diff_avg_out_of_state  diff_num_in_state  diff_num_out_of_state  \
# 0                   0.09               0.43                   0.00
# 1                  -0.01              -0.15                  -0.32
# 2                  -0.05              -0.02                   0.19
# 3                   0.47              -0.06                  -0.37
# 4                   0.03              -0.06                  -0.31
# 5                   1.06              -0.34                  -0.66
#
#    diff_med_in_state  diff_med_out_of_state  diff_sum_in_state  \
# 0               0.00                  -0.20               0.94
# 1               0.25                   0.40              -0.15
# 2               1.00                   0.43               0.09
# 3               1.00                   4.00               0.20
# 4               0.60                   1.00               0.10
# 5               1.50                   4.00               0.14
#
#    diff_sum_out_of_state
# 0                   0.09
# 1                  -0.33
# 2                   0.13
# 3                  -0.08
# 4                  -0.29
# 5                  -0.30

# %% [markdown]
# Rearrange the columns.

# %%
contributions_by_party_office = contributions_by_party_office[["year", "standardized_office",
                                  "num_dem_in_state", "num_rep_in_state", "diff_num_in_state",
                                  "num_dem_out_of_state", "num_rep_out_of_state", "diff_num_out_of_state",
                                  "avg_dem_in_state", "avg_rep_in_state", "diff_avg_in_state",
                                  "avg_dem_out_of_state", "avg_rep_out_of_state", "diff_avg_out_of_state",
                                  "med_dem_in_state", "med_rep_in_state", "diff_med_in_state",
                                  "med_dem_out_of_state", "med_rep_out_of_state", "diff_med_out_of_state",
                                  "sum_dem_in_state", "sum_rep_in_state", "diff_sum_in_state",
                                  "sum_dem_out_of_state", "sum_rep_out_of_state", "diff_sum_out_of_state"]]
contributions_by_party_office
# Out:
#    year           standardized_office  num_dem_in_state  num_rep_in_state  \
# 0  2010  GOVERNOR/LIEUTENANT GOVERNOR        305,356.00        436,151.00
# 1  2010   STATE HOUSE/ASSEMBLY/SENATE        658,609.00        557,950.00
# 2  2014  GOVERNOR/LIEUTENANT GOVERNOR        343,657.00        335,088.00
# 3  2014   STATE HOUSE/ASSEMBLY/SENATE        564,875.00        532,252.00
# 4  2018  GOVERNOR/LIEUTENANT GOVERNOR        495,128.00        465,667.00
# 5  2018   STATE HOUSE/ASSEMBLY/SENATE        662,957.00        436,078.00
#
#    diff_num_in_state  num_dem_out_of_state  num_rep_out_of_state  \
# 0               0.43             33,393.00             33,494.00
# 1              -0.15             58,032.00             39,202.00
# 2              -0.02             92,719.00            110,509.00
# 3              -0.06             74,246.00             46,714.00
# 4              -0.06            214,778.00            148,855.00
# 5              -0.34            116,008.00             39,711.00
#
#    diff_num_out_of_state  avg_dem_in_state  avg_rep_in_state  \
# 0                   0.00            816.77          1,106.53
# 1                  -0.32            414.35            414.63
# 2                   0.19            606.98            676.67
# 3                  -0.37            423.85            539.82
# 4                  -0.31            901.61          1,056.14
# 5                  -0.66            378.54            656.45
#
#    diff_avg_in_state  avg_dem_out_of_state  avg_rep_out_of_state  \
# 0               0.35              1,071.46              1,168.91
# 1               0.00                494.21                489.93
# 2               0.11                490.08                466.36
# 3               0.27                411.31                603.68
# 4               0.17                278.51                286.40
# 5               0.73                356.38                732.62
#
#    diff_avg_out_of_state  med_dem_in_state  med_rep_in_state  \
# 0                   0.09            100.00            100.00
# 1                  -0.01            100.00            125.00
# 2                  -0.05             50.00            100.00
# 3                   0.47            100.00            200.00
# 4                   0.03             50.00             80.00
# 5                   1.06            100.00            250.00
#
#    diff_med_in_state  med_dem_out_of_state  med_rep_out_of_state  \
# 0               0.00                250.00                200.00
# 1               0.25                250.00                350.00
# 2               1.00                 35.00                 50.00
# 3               1.00                100.00                500.00
# 4               0.60                 25.00                 50.00
# 5               1.50                100.00                500.00
#
#    diff_med_out_of_state  sum_dem_in_state  sum_rep_in_state  \
# 0                  -0.20    249,405,839.52    482,613,987.05
# 1                   0.40    272,893,234.09    231,341,884.21
# 2                   0.43    208,592,453.21    226,742,799.24
# 3                   4.00    239,422,578.44    287,319,524.73
# 4                   1.00    446,414,596.86    491,807,244.52
# 5                   4.00    250,955,888.64    286,263,804.75
#
#    diff_sum_in_state  sum_dem_out_of_state  sum_rep_out_of_state  \
# 0               0.94         35,779,114.12         39,151,620.03
# 1              -0.15         28,680,059.56         19,206,369.09
# 2               0.09         45,439,296.05         51,536,542.44
# 3               0.20         30,538,086.59         28,200,167.11
# 4               0.10         59,816,942.73         42,632,032.87
# 5               0.14         41,343,033.37         29,093,022.07
#
#    diff_sum_out_of_state
# 0                   0.09
# 1                  -0.33
# 2                   0.13
# 3                  -0.08
# 4                  -0.29
# 5                  -0.30

# %% [markdown]
# ## Is there a difference in the average out-of-state contributor to Democratic vs. Republican candidates?

# %% [markdown]
# First, group the data by contributor.

# %%
contributors = contributions.groupby(["year", "party", "standardized_office", "in_out_state", "contributor"])["amount"].sum().reset_index()
contributors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3824804 entries, 0 to 3824803
# Data columns (total 6 columns):
# year                   int64
# party                  object
# standardized_office    object
# in_out_state           object
# contributor            object
# amount                 float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 175.1+ MB

# %% [markdown]
# Then group by year, party, office and in-vs.-out-of-state contribution status and calculate the total contributions, average contributions, median contributions and number of contributors per group.

# %%
contributors_by_party_office = contributors.groupby(["year", "party", "standardized_office", "in_out_state"])["amount"].agg([sum, np.average, "median", len]).reset_index()
contributors_by_party_office
# Out:
#     year        party           standardized_office  in_out_state  \
# 0   2010   Democratic  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 1   2010   Democratic  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 2   2010   Democratic  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 3   2010   Democratic   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 4   2010   Democratic   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 5   2010   Democratic   STATE HOUSE/ASSEMBLY/SENATE       unknown
# 6   2010  Nonpartisan   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 7   2010  Nonpartisan   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 8   2010  Nonpartisan   STATE HOUSE/ASSEMBLY/SENATE       unknown
# 9   2010   Republican  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 10  2010   Republican  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 11  2010   Republican  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 12  2010   Republican   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 13  2010   Republican   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 14  2010   Republican   STATE HOUSE/ASSEMBLY/SENATE       unknown
# 15  2010  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 16  2010  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 17  2010  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 18  2010  Third-Party   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 19  2010  Third-Party   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 20  2010  Third-Party   STATE HOUSE/ASSEMBLY/SENATE       unknown
# 21  2014   Democratic  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 22  2014   Democratic  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 23  2014   Democratic  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 24  2014   Democratic   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 25  2014   Democratic   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 26  2014   Democratic   STATE HOUSE/ASSEMBLY/SENATE       unknown
# 27  2014  Nonpartisan   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 28  2014  Nonpartisan   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 29  2014  Nonpartisan   STATE HOUSE/ASSEMBLY/SENATE       unknown
# 30  2014   Republican  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 31  2014   Republican  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 32  2014   Republican  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 33  2014   Republican   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 34  2014   Republican   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 35  2014   Republican   STATE HOUSE/ASSEMBLY/SENATE       unknown
# 36  2014  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 37  2014  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 38  2014  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 39  2014  Third-Party   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 40  2014  Third-Party   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 41  2014  Third-Party   STATE HOUSE/ASSEMBLY/SENATE       unknown
# 42  2018   Democratic  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 43  2018   Democratic  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 44  2018   Democratic  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 45  2018   Democratic   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 46  2018   Democratic   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 47  2018   Democratic   STATE HOUSE/ASSEMBLY/SENATE       unknown
# 48  2018  Nonpartisan   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 49  2018  Nonpartisan   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 50  2018  Nonpartisan   STATE HOUSE/ASSEMBLY/SENATE       unknown
# 51  2018   Republican  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 52  2018   Republican  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 53  2018   Republican  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 54  2018   Republican   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 55  2018   Republican   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 56  2018   Republican   STATE HOUSE/ASSEMBLY/SENATE       unknown
# 57  2018  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 58  2018  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 59  2018  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 60  2018  Third-Party   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 61  2018  Third-Party   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 62  2018  Third-Party   STATE HOUSE/ASSEMBLY/SENATE       unknown
#
#               sum   average   median        len
# 0  249,405,839.52  1,236.21   175.00 201,750.00
# 1   35,779,114.12  1,485.84   250.00  24,080.00
# 2      369,604.83    605.91   250.00     610.00
# 3  272,893,234.09    811.46   100.00 336,297.00
# 4   28,679,809.56  1,026.85   120.00  27,930.00
# 5    1,342,191.95    446.50   100.00   3,006.00
# 6    1,001,559.24  2,491.44   500.00     402.00
# 7      143,053.70  2,135.13 1,000.00      67.00
# 8      -19,438.72 -1,495.29  -500.00      13.00
# 9  482,613,812.05  1,731.69   135.00 278,695.00
# 10  39,151,620.03  1,531.39   250.00  25,566.00
# 11     240,109.43    626.92   100.00     383.00
# 12 231,341,884.21    741.93   125.00 311,809.00
# 13  19,206,319.09  1,209.85   200.00  15,875.00
# 14     639,587.51    402.26   100.00   1,590.00
# 15   3,627,843.15    387.14   100.00   9,371.00
# 16     554,492.88    150.35    50.00   3,688.00
# 17   1,626,288.15 27,564.21   100.00      59.00
# 18   3,345,511.14    499.18   100.00   6,702.00
# 19     309,124.31    503.46   150.00     614.00
# 20       1,431.48     16.27    50.00      88.00
# 21 208,592,453.21  1,091.98   100.00 191,022.00
# 22  45,439,296.05    825.45    95.00  55,048.00
# 23   1,783,287.65    343.67   180.00   5,189.00
# 24 239,422,578.44    796.90   100.00 300,444.00
# 25  30,538,086.59    732.66   100.00  41,681.00
# 26   4,522,351.40    338.83   100.00  13,347.00
# 27   1,788,615.01  1,409.47   500.00   1,269.00
# 28     182,893.05  1,325.31   500.00     138.00
# 29       4,068.00    581.14   500.00       7.00
# 30 226,742,799.24  1,106.21   100.00 204,972.00
# 31  51,536,542.44    816.12    75.00  63,148.00
# 32   8,468,869.94  2,349.85    50.00   3,604.00
# 33 287,319,475.73  1,031.80   150.00 278,465.00
# 34  28,200,167.11  1,851.86   200.00  15,228.00
# 35   2,741,740.55    760.96   130.00   3,603.00
# 36   9,026,796.83  1,988.28   125.00   4,540.00
# 37     377,039.85    440.98   250.00     855.00
# 38      20,805.96    671.16    50.00      31.00
# 39   3,993,147.45    655.58   100.00   6,091.00
# 40     257,766.09    348.80   100.00     739.00
# 41      19,480.08    526.49   300.00      37.00
# 42 446,414,076.86  1,808.50   100.00 246,842.00
# 43  59,816,870.05    495.66    30.00 120,681.00
# 44   3,210,357.50  2,028.02    50.00   1,583.00
# 45 250,955,375.64    732.52   100.00 342,590.00
# 46  41,341,934.37    638.70   100.00  64,728.00
# 47   6,907,616.51    415.45   120.00  16,627.00
# 48   1,642,246.38  1,748.93   500.00     939.00
# 49     336,165.87  2,848.86 1,000.00     118.00
# 50      -2,307.58   -256.40   500.00       9.00
# 51 491,806,944.52  2,012.84   141.20 244,335.00
# 52  42,632,032.87    499.31    75.00  85,382.00
# 53   3,984,424.72  4,284.33   250.00     930.00
# 54 286,263,329.75  1,236.44   200.00 231,522.00
# 55  29,093,022.07  2,201.35   250.00  13,216.00
# 56   5,489,302.33    619.14   250.00   8,866.00
# 57   2,450,299.02    603.97   100.00   4,057.00
# 58     192,962.51    229.17   100.00     842.00
# 59     419,218.37  4,556.72    50.00      92.00
# 60     869,671.44    329.05   100.00   2,643.00
# 61     146,916.86    202.64    50.00     725.00
# 62      67,030.91  2,792.95   185.00      24.00

# %% [markdown]
# Drop non-major parties and unknown contribution statuses.

# %%
contributors_by_party_office = contributors_by_party_office[((contributors_by_party_office["party"] == "Democratic") | (contributors_by_party_office["party"] == "Republican")) & (contributors_by_party_office["in_out_state"] != "unknown")]
contributors_by_party_office
# Out:
#     year       party           standardized_office  in_out_state  \
# 0   2010  Democratic  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 1   2010  Democratic  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 3   2010  Democratic   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 4   2010  Democratic   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 9   2010  Republican  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 10  2010  Republican  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 12  2010  Republican   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 13  2010  Republican   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 21  2014  Democratic  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 22  2014  Democratic  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 24  2014  Democratic   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 25  2014  Democratic   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 30  2014  Republican  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 31  2014  Republican  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 33  2014  Republican   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 34  2014  Republican   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 42  2018  Democratic  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 43  2018  Democratic  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 45  2018  Democratic   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 46  2018  Democratic   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
# 51  2018  Republican  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 52  2018  Republican  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 54  2018  Republican   STATE HOUSE/ASSEMBLY/SENATE      in-state
# 55  2018  Republican   STATE HOUSE/ASSEMBLY/SENATE  out-of-state
#
#               sum  average  median        len
# 0  249,405,839.52 1,236.21  175.00 201,750.00
# 1   35,779,114.12 1,485.84  250.00  24,080.00
# 3  272,893,234.09   811.46  100.00 336,297.00
# 4   28,679,809.56 1,026.85  120.00  27,930.00
# 9  482,613,812.05 1,731.69  135.00 278,695.00
# 10  39,151,620.03 1,531.39  250.00  25,566.00
# 12 231,341,884.21   741.93  125.00 311,809.00
# 13  19,206,319.09 1,209.85  200.00  15,875.00
# 21 208,592,453.21 1,091.98  100.00 191,022.00
# 22  45,439,296.05   825.45   95.00  55,048.00
# 24 239,422,578.44   796.90  100.00 300,444.00
# 25  30,538,086.59   732.66  100.00  41,681.00
# 30 226,742,799.24 1,106.21  100.00 204,972.00
# 31  51,536,542.44   816.12   75.00  63,148.00
# 33 287,319,475.73 1,031.80  150.00 278,465.00
# 34  28,200,167.11 1,851.86  200.00  15,228.00
# 42 446,414,076.86 1,808.50  100.00 246,842.00
# 43  59,816,870.05   495.66   30.00 120,681.00
# 45 250,955,375.64   732.52  100.00 342,590.00
# 46  41,341,934.37   638.70  100.00  64,728.00
# 51 491,806,944.52 2,012.84  141.20 244,335.00
# 52  42,632,032.87   499.31   75.00  85,382.00
# 54 286,263,329.75 1,236.44  200.00 231,522.00
# 55  29,093,022.07 2,201.35  250.00  13,216.00

# %% [markdown]
# Pivot dataframe to aggregate each year and office's data in a single row.

# %%
contributors_by_party_office = pd.pivot_table(contributors_by_party_office, index=["year", "standardized_office"], columns=["party", "in_out_state"]).reset_index()
contributors_by_party_office
# Out:
#               year           standardized_office    average               \
# party                                            Democratic
# in_out_state                                       in-state out-of-state
# 0             2010  GOVERNOR/LIEUTENANT GOVERNOR   1,236.21     1,485.84
# 1             2010   STATE HOUSE/ASSEMBLY/SENATE     811.46     1,026.85
# 2             2014  GOVERNOR/LIEUTENANT GOVERNOR   1,091.98       825.45
# 3             2014   STATE HOUSE/ASSEMBLY/SENATE     796.90       732.66
# 4             2018  GOVERNOR/LIEUTENANT GOVERNOR   1,808.50       495.66
# 5             2018   STATE HOUSE/ASSEMBLY/SENATE     732.52       638.70
#
#                                             len                          \
# party        Republican              Democratic              Republican
# in_out_state   in-state out-of-state   in-state out-of-state   in-state
# 0              1,731.69     1,531.39 201,750.00    24,080.00 278,695.00
# 1                741.93     1,209.85 336,297.00    27,930.00 311,809.00
# 2              1,106.21       816.12 191,022.00    55,048.00 204,972.00
# 3              1,031.80     1,851.86 300,444.00    41,681.00 278,465.00
# 4              2,012.84       499.31 246,842.00   120,681.00 244,335.00
# 5              1,236.44     2,201.35 342,590.00    64,728.00 231,522.00
#
#                               median                                       \
# party                     Democratic              Republican
# in_out_state out-of-state   in-state out-of-state   in-state out-of-state
# 0               25,566.00     175.00       250.00     135.00       250.00
# 1               15,875.00     100.00       120.00     125.00       200.00
# 2               63,148.00     100.00        95.00     100.00        75.00
# 3               15,228.00     100.00       100.00     150.00       200.00
# 4               85,382.00     100.00        30.00     141.20        75.00
# 5               13,216.00     100.00       100.00     200.00       250.00
#
#                         sum
# party            Democratic                   Republican
# in_out_state       in-state  out-of-state       in-state  out-of-state
# 0            249,405,839.52 35,779,114.12 482,613,812.05 39,151,620.03
# 1            272,893,234.09 28,679,809.56 231,341,884.21 19,206,319.09
# 2            208,592,453.21 45,439,296.05 226,742,799.24 51,536,542.44
# 3            239,422,578.44 30,538,086.59 287,319,475.73 28,200,167.11
# 4            446,414,076.86 59,816,870.05 491,806,944.52 42,632,032.87
# 5            250,955,375.64 41,341,934.37 286,263,329.75 29,093,022.07

# %% [markdown]
# Flatten the resulting dataframe's multi-index columns.

# %%
contributors_by_party_office.columns = ["year", "standardized_office",
                                  "avg_dem_in_state", "avg_dem_out_of_state",
                                  "avg_rep_in_state", "avg_rep_out_of_state",
                                  "num_dem_in_state", "num_dem_out_of_state",
                                  "num_rep_in_state", "num_rep_out_of_state",
                                  "med_dem_in_state", "med_dem_out_of_state",
                                  "med_rep_in_state", "med_rep_out_of_state",
                                  "sum_dem_in_state", "sum_dem_out_of_state",
                                  "sum_rep_in_state", "sum_rep_out_of_state"
                                  ]
contributors_by_party_office
# Out:
#    year           standardized_office  avg_dem_in_state  avg_dem_out_of_state  \
# 0  2010  GOVERNOR/LIEUTENANT GOVERNOR          1,236.21              1,485.84
# 1  2010   STATE HOUSE/ASSEMBLY/SENATE            811.46              1,026.85
# 2  2014  GOVERNOR/LIEUTENANT GOVERNOR          1,091.98                825.45
# 3  2014   STATE HOUSE/ASSEMBLY/SENATE            796.90                732.66
# 4  2018  GOVERNOR/LIEUTENANT GOVERNOR          1,808.50                495.66
# 5  2018   STATE HOUSE/ASSEMBLY/SENATE            732.52                638.70
#
#    avg_rep_in_state  avg_rep_out_of_state  num_dem_in_state  \
# 0          1,731.69              1,531.39        201,750.00
# 1            741.93              1,209.85        336,297.00
# 2          1,106.21                816.12        191,022.00
# 3          1,031.80              1,851.86        300,444.00
# 4          2,012.84                499.31        246,842.00
# 5          1,236.44              2,201.35        342,590.00
#
#    num_dem_out_of_state  num_rep_in_state  num_rep_out_of_state  \
# 0             24,080.00        278,695.00             25,566.00
# 1             27,930.00        311,809.00             15,875.00
# 2             55,048.00        204,972.00             63,148.00
# 3             41,681.00        278,465.00             15,228.00
# 4            120,681.00        244,335.00             85,382.00
# 5             64,728.00        231,522.00             13,216.00
#
#    med_dem_in_state  med_dem_out_of_state  med_rep_in_state  \
# 0            175.00                250.00            135.00
# 1            100.00                120.00            125.00
# 2            100.00                 95.00            100.00
# 3            100.00                100.00            150.00
# 4            100.00                 30.00            141.20
# 5            100.00                100.00            200.00
#
#    med_rep_out_of_state  sum_dem_in_state  sum_dem_out_of_state  \
# 0                250.00    249,405,839.52         35,779,114.12
# 1                200.00    272,893,234.09         28,679,809.56
# 2                 75.00    208,592,453.21         45,439,296.05
# 3                200.00    239,422,578.44         30,538,086.59
# 4                 75.00    446,414,076.86         59,816,870.05
# 5                250.00    250,955,375.64         41,341,934.37
#
#    sum_rep_in_state  sum_rep_out_of_state
# 0    482,613,812.05         39,151,620.03
# 1    231,341,884.21         19,206,319.09
# 2    226,742,799.24         51,536,542.44
# 3    287,319,475.73         28,200,167.11
# 4    491,806,944.52         42,632,032.87
# 5    286,263,329.75         29,093,022.07

# %%
contributors_by_party_office["diff_avg_in_state"] = (contributors_by_party_office["avg_rep_in_state"] - contributors_by_party_office["avg_dem_in_state"]) / contributors_by_party_office["avg_dem_in_state"]
contributors_by_party_office["diff_avg_out_of_state"] = (contributors_by_party_office["avg_rep_out_of_state"] - contributors_by_party_office["avg_dem_out_of_state"]) / contributors_by_party_office["avg_dem_out_of_state"]
contributors_by_party_office["diff_num_in_state"] = (contributors_by_party_office["num_rep_in_state"] - contributors_by_party_office["num_dem_in_state"]) / contributors_by_party_office["num_dem_in_state"]
contributors_by_party_office["diff_num_out_of_state"] = (contributors_by_party_office["num_rep_out_of_state"] - contributors_by_party_office["num_dem_out_of_state"]) / contributors_by_party_office["num_dem_out_of_state"]
contributors_by_party_office["diff_med_in_state"] = (contributors_by_party_office["med_rep_in_state"] - contributors_by_party_office["med_dem_in_state"]) / contributors_by_party_office["med_dem_in_state"]
contributors_by_party_office["diff_med_out_of_state"] = (contributors_by_party_office["med_rep_out_of_state"] - contributors_by_party_office["med_dem_out_of_state"]) / contributors_by_party_office["med_dem_out_of_state"]
contributors_by_party_office["diff_sum_in_state"] = (contributors_by_party_office["sum_rep_in_state"] - contributors_by_party_office["sum_dem_in_state"]) / contributors_by_party_office["sum_dem_in_state"]
contributors_by_party_office["diff_sum_out_of_state"] = (contributors_by_party_office["sum_rep_out_of_state"] - contributors_by_party_office["sum_dem_out_of_state"]) / contributors_by_party_office["sum_dem_out_of_state"]
contributors_by_party_office
# Out:
#    year           standardized_office  avg_dem_in_state  avg_dem_out_of_state  \
# 0  2010  GOVERNOR/LIEUTENANT GOVERNOR          1,236.21              1,485.84
# 1  2010   STATE HOUSE/ASSEMBLY/SENATE            811.46              1,026.85
# 2  2014  GOVERNOR/LIEUTENANT GOVERNOR          1,091.98                825.45
# 3  2014   STATE HOUSE/ASSEMBLY/SENATE            796.90                732.66
# 4  2018  GOVERNOR/LIEUTENANT GOVERNOR          1,808.50                495.66
# 5  2018   STATE HOUSE/ASSEMBLY/SENATE            732.52                638.70
#
#    avg_rep_in_state  avg_rep_out_of_state  num_dem_in_state  \
# 0          1,731.69              1,531.39        201,750.00
# 1            741.93              1,209.85        336,297.00
# 2          1,106.21                816.12        191,022.00
# 3          1,031.80              1,851.86        300,444.00
# 4          2,012.84                499.31        246,842.00
# 5          1,236.44              2,201.35        342,590.00
#
#    num_dem_out_of_state  num_rep_in_state  num_rep_out_of_state  \
# 0             24,080.00        278,695.00             25,566.00
# 1             27,930.00        311,809.00             15,875.00
# 2             55,048.00        204,972.00             63,148.00
# 3             41,681.00        278,465.00             15,228.00
# 4            120,681.00        244,335.00             85,382.00
# 5             64,728.00        231,522.00             13,216.00
#
#    med_dem_in_state  med_dem_out_of_state  med_rep_in_state  \
# 0            175.00                250.00            135.00
# 1            100.00                120.00            125.00
# 2            100.00                 95.00            100.00
# 3            100.00                100.00            150.00
# 4            100.00                 30.00            141.20
# 5            100.00                100.00            200.00
#
#    med_rep_out_of_state  sum_dem_in_state  sum_dem_out_of_state  \
# 0                250.00    249,405,839.52         35,779,114.12
# 1                200.00    272,893,234.09         28,679,809.56
# 2                 75.00    208,592,453.21         45,439,296.05
# 3                200.00    239,422,578.44         30,538,086.59
# 4                 75.00    446,414,076.86         59,816,870.05
# 5                250.00    250,955,375.64         41,341,934.37
#
#    sum_rep_in_state  sum_rep_out_of_state  diff_avg_in_state  \
# 0    482,613,812.05         39,151,620.03               0.40
# 1    231,341,884.21         19,206,319.09              -0.09
# 2    226,742,799.24         51,536,542.44               0.01
# 3    287,319,475.73         28,200,167.11               0.29
# 4    491,806,944.52         42,632,032.87               0.11
# 5    286,263,329.75         29,093,022.07               0.69
#
#    diff_avg_out_of_state  diff_num_in_state  diff_num_out_of_state  \
# 0                   0.03               0.38                   0.06
# 1                   0.18              -0.07                  -0.43
# 2                  -0.01               0.07                   0.15
# 3                   1.53              -0.07                  -0.63
# 4                   0.01              -0.01                  -0.29
# 5                   2.45              -0.32                  -0.80
#
#    diff_med_in_state  diff_med_out_of_state  diff_sum_in_state  \
# 0              -0.23                   0.00               0.94
# 1               0.25                   0.67              -0.15
# 2               0.00                  -0.21               0.09
# 3               0.50                   1.00               0.20
# 4               0.41                   1.50               0.10
# 5               1.00                   1.50               0.14
#
#    diff_sum_out_of_state
# 0                   0.09
# 1                  -0.33
# 2                   0.13
# 3                  -0.08
# 4                  -0.29
# 5                  -0.30

# %% [markdown]
# Rearrange the columns.

# %%
contributors_by_party_office = contributors_by_party_office[["year", "standardized_office",
                                  "num_dem_in_state", "num_rep_in_state", "diff_num_in_state",
                                  "num_dem_out_of_state", "num_rep_out_of_state", "diff_num_out_of_state",
                                  "avg_dem_in_state", "avg_rep_in_state", "diff_avg_in_state",
                                  "avg_dem_out_of_state", "avg_rep_out_of_state", "diff_avg_out_of_state",
                                  "med_dem_in_state", "med_rep_in_state", "diff_med_in_state",
                                  "med_dem_out_of_state", "med_rep_out_of_state", "diff_med_out_of_state",
                                  "sum_dem_in_state", "sum_rep_in_state", "diff_sum_in_state",
                                  "sum_dem_out_of_state", "sum_rep_out_of_state", "diff_sum_out_of_state"]]
contributors_by_party_office
# Out:
#    year           standardized_office  num_dem_in_state  num_rep_in_state  \
# 0  2010  GOVERNOR/LIEUTENANT GOVERNOR        201,750.00        278,695.00
# 1  2010   STATE HOUSE/ASSEMBLY/SENATE        336,297.00        311,809.00
# 2  2014  GOVERNOR/LIEUTENANT GOVERNOR        191,022.00        204,972.00
# 3  2014   STATE HOUSE/ASSEMBLY/SENATE        300,444.00        278,465.00
# 4  2018  GOVERNOR/LIEUTENANT GOVERNOR        246,842.00        244,335.00
# 5  2018   STATE HOUSE/ASSEMBLY/SENATE        342,590.00        231,522.00
#
#    diff_num_in_state  num_dem_out_of_state  num_rep_out_of_state  \
# 0               0.38             24,080.00             25,566.00
# 1              -0.07             27,930.00             15,875.00
# 2               0.07             55,048.00             63,148.00
# 3              -0.07             41,681.00             15,228.00
# 4              -0.01            120,681.00             85,382.00
# 5              -0.32             64,728.00             13,216.00
#
#    diff_num_out_of_state  avg_dem_in_state  avg_rep_in_state  \
# 0                   0.06          1,236.21          1,731.69
# 1                  -0.43            811.46            741.93
# 2                   0.15          1,091.98          1,106.21
# 3                  -0.63            796.90          1,031.80
# 4                  -0.29          1,808.50          2,012.84
# 5                  -0.80            732.52          1,236.44
#
#    diff_avg_in_state  avg_dem_out_of_state  avg_rep_out_of_state  \
# 0               0.40              1,485.84              1,531.39
# 1              -0.09              1,026.85              1,209.85
# 2               0.01                825.45                816.12
# 3               0.29                732.66              1,851.86
# 4               0.11                495.66                499.31
# 5               0.69                638.70              2,201.35
#
#    diff_avg_out_of_state  med_dem_in_state  med_rep_in_state  \
# 0                   0.03            175.00            135.00
# 1                   0.18            100.00            125.00
# 2                  -0.01            100.00            100.00
# 3                   1.53            100.00            150.00
# 4                   0.01            100.00            141.20
# 5                   2.45            100.00            200.00
#
#    diff_med_in_state  med_dem_out_of_state  med_rep_out_of_state  \
# 0              -0.23                250.00                250.00
# 1               0.25                120.00                200.00
# 2               0.00                 95.00                 75.00
# 3               0.50                100.00                200.00
# 4               0.41                 30.00                 75.00
# 5               1.00                100.00                250.00
#
#    diff_med_out_of_state  sum_dem_in_state  sum_rep_in_state  \
# 0                   0.00    249,405,839.52    482,613,812.05
# 1                   0.67    272,893,234.09    231,341,884.21
# 2                  -0.21    208,592,453.21    226,742,799.24
# 3                   1.00    239,422,578.44    287,319,475.73
# 4                   1.50    446,414,076.86    491,806,944.52
# 5                   1.50    250,955,375.64    286,263,329.75
#
#    diff_sum_in_state  sum_dem_out_of_state  sum_rep_out_of_state  \
# 0               0.94         35,779,114.12         39,151,620.03
# 1              -0.15         28,679,809.56         19,206,319.09
# 2               0.09         45,439,296.05         51,536,542.44
# 3               0.20         30,538,086.59         28,200,167.11
# 4               0.10         59,816,870.05         42,632,032.87
# 5               0.14         41,341,934.37         29,093,022.07
#
#    diff_sum_out_of_state
# 0                   0.09
# 1                  -0.33
# 2                   0.13
# 3                  -0.08
# 4                  -0.29
# 5                  -0.30

# %% [markdown]
# ## Export the data

# %%
writer = pd.ExcelWriter("data/contributors_analysis.xlsx")
contributions_by_party_office.to_excel(writer, "contributions_by_party_office", index=False)
contributors_by_party_office.to_excel(writer, "contributors_by_party_office", index=False)
writer.save()
