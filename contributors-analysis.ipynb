# %% [markdown]
# # Out-of-State-Contributions: Contributors Analysis
#
# How much out-of-state money are contributors donating in the 2018 election cycle thus far and how does that compare with this point in the 2014 and 2010 cycles?

# %%
import numpy as np
import pandas as pd

# %load_ext jupyternotify

pd.set_option("display.max_columns", 100)
pd.set_option("display.max_rows", 500)
pd.options.display.float_format = "{:,.2f}".format # Format floats

# %% [markdown]
# Import contributions data.

# %%
# %%notify
# contributions = pd.read_csv("data/contributions.csv")
# contributions.info()
# Out:
# /home/joe/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (10,13,14,15,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362352 entries, 0 to 6362351
# Data columns (total 19 columns):
# candidate                 object
# candidate_id              int64
# year                      int64
# state                     object
# party                     object
# election_status           object
# contributor               object
# amount                    float64
# date                      object
# in_out_state              object
# no_veto                   object
# office                    object
# latest_month              object
# redistricting_role        object
# independent_commission    object
# single_house_district     object
# standardized_office       object
# standardized_status       object
# two_year_term             object
# dtypes: float64(1), int64(2), object(16)
# memory usage: 922.3+ MB

# %% [markdown]
# Convert the contribution date and latest month columns to datetime data type.

# %%
contributions["date"] = pd.to_datetime(contributions["date"], errors="coerce")
contributions["latest_month"] = pd.to_datetime(contributions["latest_month"], errors="coerce")
contributions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362352 entries, 0 to 6362351
# Data columns (total 19 columns):
# candidate                 object
# candidate_id              int64
# year                      int64
# state                     object
# party                     object
# election_status           object
# contributor               object
# amount                    float64
# date                      datetime64[ns]
# in_out_state              object
# no_veto                   object
# office                    object
# latest_month              datetime64[ns]
# redistricting_role        object
# independent_commission    object
# single_house_district     object
# standardized_office       object
# standardized_status       object
# two_year_term             object
# dtypes: datetime64[ns](2), float64(1), int64(2), object(14)
# memory usage: 922.3+ MB

# %% [markdown]
# ## Is there a difference in the average out-of-state contribution to Democratic vs. Republican candidates?

# %% [markdown]
# Group by year, party, office and in-vs.-out-of-state contribution status and calculate the total contributions, average contributions and median contributions per group.

# %%
contributions_by_party_office = contributions.groupby(["year", "party", "standardized_office", "in_out_state"])["amount"].agg([sum, np.average, "median"]).reset_index()
contributions_by_party_office
# Out:
#     year        party           standardized_office  in_out_state  \
# 0   2010   Democratic  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 1   2010   Democratic  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 2   2010   Democratic  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 3   2010   Democratic          STATE HOUSE/ASSEMBLY      in-state
# 4   2010   Democratic          STATE HOUSE/ASSEMBLY  out-of-state
# 5   2010   Democratic          STATE HOUSE/ASSEMBLY       unknown
# 6   2010   Democratic                  STATE SENATE      in-state
# 7   2010   Democratic                  STATE SENATE  out-of-state
# 8   2010   Democratic                  STATE SENATE       unknown
# 9   2010  Nonpartisan                  STATE SENATE      in-state
# 10  2010  Nonpartisan                  STATE SENATE  out-of-state
# 11  2010  Nonpartisan                  STATE SENATE       unknown
# 12  2010   Republican  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 13  2010   Republican  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 14  2010   Republican  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 15  2010   Republican          STATE HOUSE/ASSEMBLY      in-state
# 16  2010   Republican          STATE HOUSE/ASSEMBLY  out-of-state
# 17  2010   Republican          STATE HOUSE/ASSEMBLY       unknown
# 18  2010   Republican                  STATE SENATE      in-state
# 19  2010   Republican                  STATE SENATE  out-of-state
# 20  2010   Republican                  STATE SENATE       unknown
# 21  2010  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 22  2010  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 23  2010  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 24  2010  Third-Party          STATE HOUSE/ASSEMBLY      in-state
# 25  2010  Third-Party          STATE HOUSE/ASSEMBLY  out-of-state
# 26  2010  Third-Party          STATE HOUSE/ASSEMBLY       unknown
# 27  2010  Third-Party                  STATE SENATE      in-state
# 28  2010  Third-Party                  STATE SENATE  out-of-state
# 29  2010  Third-Party                  STATE SENATE       unknown
# 30  2014   Democratic  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 31  2014   Democratic  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 32  2014   Democratic  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 33  2014   Democratic          STATE HOUSE/ASSEMBLY      in-state
# 34  2014   Democratic          STATE HOUSE/ASSEMBLY  out-of-state
# 35  2014   Democratic          STATE HOUSE/ASSEMBLY       unknown
# 36  2014   Democratic                  STATE SENATE      in-state
# 37  2014   Democratic                  STATE SENATE  out-of-state
# 38  2014   Democratic                  STATE SENATE       unknown
# 39  2014  Nonpartisan                  STATE SENATE      in-state
# 40  2014  Nonpartisan                  STATE SENATE  out-of-state
# 41  2014  Nonpartisan                  STATE SENATE       unknown
# 42  2014   Republican  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 43  2014   Republican  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 44  2014   Republican  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 45  2014   Republican          STATE HOUSE/ASSEMBLY      in-state
# 46  2014   Republican          STATE HOUSE/ASSEMBLY  out-of-state
# 47  2014   Republican          STATE HOUSE/ASSEMBLY       unknown
# 48  2014   Republican                  STATE SENATE      in-state
# 49  2014   Republican                  STATE SENATE  out-of-state
# 50  2014   Republican                  STATE SENATE       unknown
# 51  2014  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 52  2014  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 53  2014  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 54  2014  Third-Party          STATE HOUSE/ASSEMBLY      in-state
# 55  2014  Third-Party          STATE HOUSE/ASSEMBLY  out-of-state
# 56  2014  Third-Party          STATE HOUSE/ASSEMBLY       unknown
# 57  2014  Third-Party                  STATE SENATE      in-state
# 58  2014  Third-Party                  STATE SENATE  out-of-state
# 59  2014  Third-Party                  STATE SENATE       unknown
# 60  2018   Democratic  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 61  2018   Democratic  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 62  2018   Democratic  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 63  2018   Democratic          STATE HOUSE/ASSEMBLY      in-state
# 64  2018   Democratic          STATE HOUSE/ASSEMBLY  out-of-state
# 65  2018   Democratic          STATE HOUSE/ASSEMBLY       unknown
# 66  2018   Democratic                  STATE SENATE      in-state
# 67  2018   Democratic                  STATE SENATE  out-of-state
# 68  2018   Democratic                  STATE SENATE       unknown
# 69  2018  Nonpartisan          STATE HOUSE/ASSEMBLY      in-state
# 70  2018  Nonpartisan          STATE HOUSE/ASSEMBLY  out-of-state
# 71  2018  Nonpartisan                  STATE SENATE      in-state
# 72  2018  Nonpartisan                  STATE SENATE  out-of-state
# 73  2018  Nonpartisan                  STATE SENATE       unknown
# 74  2018   Republican  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 75  2018   Republican  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 76  2018   Republican  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 77  2018   Republican          STATE HOUSE/ASSEMBLY      in-state
# 78  2018   Republican          STATE HOUSE/ASSEMBLY  out-of-state
# 79  2018   Republican          STATE HOUSE/ASSEMBLY       unknown
# 80  2018   Republican                  STATE SENATE      in-state
# 81  2018   Republican                  STATE SENATE  out-of-state
# 82  2018   Republican                  STATE SENATE       unknown
# 83  2018  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 84  2018  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 85  2018  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 86  2018  Third-Party          STATE HOUSE/ASSEMBLY      in-state
# 87  2018  Third-Party          STATE HOUSE/ASSEMBLY  out-of-state
# 88  2018  Third-Party          STATE HOUSE/ASSEMBLY       unknown
# 89  2018  Third-Party                  STATE SENATE      in-state
# 90  2018  Third-Party                  STATE SENATE  out-of-state
# 91  2018  Third-Party                  STATE SENATE       unknown
# 92  2018      Unknown  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 93  2018      Unknown  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
#
#               sum   average  median
# 0  230,772,990.78    883.76  100.00
# 1   33,055,604.70  1,135.78  250.00
# 2      330,443.83    375.93  100.00
# 3  151,477,797.79    376.82  100.00
# 4   15,521,314.60    459.62  250.00
# 5      704,006.80    302.80  100.00
# 6   88,739,830.53    447.12  150.00
# 7   10,408,953.19    604.08  400.00
# 8      524,722.16    377.50  100.00
# 9      941,726.00    459.15  300.00
# 10     136,753.70    530.05  500.00
# 11     -19,688.72 -1,406.34 -287.50
# 12 448,491,319.65  1,126.97  100.00
# 13  32,663,205.26  1,111.64  250.00
# 14     237,464.43    456.66   50.00
# 15 122,783,382.99    367.67  100.00
# 16  10,373,473.17    454.32  250.00
# 17     284,294.94    219.36  100.00
# 18  77,402,598.04    454.44  150.00
# 19   6,980,604.35    562.82  500.00
# 20     243,554.77    280.92  135.00
# 21   3,172,624.04    388.71  125.00
# 22     377,656.73    323.34  250.00
# 23   1,538,273.15 14,791.09  250.00
# 24   1,532,088.03    285.73  100.00
# 25     123,681.19    297.31  100.00
# 26       9,417.30    181.10   94.00
# 27   1,482,390.78    568.62  150.00
# 28     152,426.10    851.54  250.00
# 29     -10,803.82   -327.39   20.00
# 30 193,286,784.14    629.71   50.00
# 31  42,787,001.23    532.90   50.00
# 32   1,766,363.37    317.23  125.00
# 33 144,237,818.34    402.32  100.00
# 34  18,971,767.13    493.85  250.00
# 35   2,587,939.20    198.83  100.00
# 36  73,835,181.25    449.85  100.00
# 37   9,292,575.52    294.27   25.00
# 38   1,688,927.72    261.52  150.00
# 39   1,617,096.45    528.64  250.00
# 40     156,743.05    567.91  500.00
# 41       4,068.00    581.14  500.00
# 42 205,315,120.51    649.86  100.00
# 43  49,230,848.34    489.72   50.00
# 44   8,453,990.94  2,200.99   50.00
# 45 153,422,814.78    465.75  200.00
# 46  15,549,233.86    553.20  500.00
# 47   2,066,869.19    570.33  100.00
# 48  99,521,354.54    608.18  250.00
# 49  10,146,947.11    716.14  500.00
# 50     473,948.59    433.23  150.00
# 51   8,609,356.65  1,294.83  100.00
# 52     374,487.09    324.51  123.50
# 53      19,805.96    366.78   -0.03
# 54   1,869,669.62    380.32  100.00
# 55     134,931.14    238.82  100.00
# 56       2,014.62     95.93   50.00
# 57   1,762,007.65    696.45  125.00
# 58     108,934.58    414.20  200.00
# 59      15,343.18    958.95  500.00
# 60 428,305,926.21    958.53   50.00
# 61  56,621,009.83    353.40   25.00
# 62   3,194,401.76  1,441.52   25.00
# 63 151,960,126.31    363.15  100.00
# 64  26,389,191.67    373.44  100.00
# 65   4,305,172.43    279.21  100.00
# 66  89,132,513.88    417.15  100.00
# 67  13,363,576.52    342.82   50.00
# 68   2,675,072.96    345.93  100.00
# 69       2,897.59    160.98  150.00
# 70         350.00    350.00  350.00
# 71   1,373,439.74    545.45  250.00
# 72     310,156.30    747.36  500.00
# 73      -3,156.23   -225.44  375.00
# 74 461,971,654.98  1,040.20   88.63
# 75  41,265,310.34    290.12   50.00
# 76   3,978,262.22  3,218.66  200.00
# 77 154,267,007.84    583.19  200.00
# 78  15,738,178.18    673.67  500.00
# 79   3,295,232.06    409.35  200.00
# 80 118,109,121.82    791.73  250.00
# 81  12,025,663.89    844.20  500.00
# 82   1,898,861.56    519.81  250.00
# 83   3,001,405.04    383.76  100.00
# 84     252,867.21    220.27  100.00
# 85     518,202.42  2,578.12   25.00
# 86     638,528.03    220.11   58.85
# 87     121,910.20    174.41   50.00
# 88      28,195.91  1,342.66  200.00
# 89     176,643.05    356.14  100.00
# 90      25,016.19    133.06  100.00
# 91      15,845.00  1,980.62   50.00
# 92      28,042.01    274.92  200.00
# 93       7,944.09    567.44  450.00

# %% [markdown]
# Drop non-major parties and unknown contribution statuses.

# %%
contributions_by_party_office = contributions_by_party_office[((contributions_by_party_office["party"] == "Democratic") | (contributions_by_party_office["party"] == "Republican")) & (contributions_by_party_office["in_out_state"] != "unknown")]
contributions_by_party_office
# Out:
#     year       party           standardized_office  in_out_state  \
# 0   2010  Democratic  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 1   2010  Democratic  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 3   2010  Democratic          STATE HOUSE/ASSEMBLY      in-state
# 4   2010  Democratic          STATE HOUSE/ASSEMBLY  out-of-state
# 6   2010  Democratic                  STATE SENATE      in-state
# 7   2010  Democratic                  STATE SENATE  out-of-state
# 12  2010  Republican  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 13  2010  Republican  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 15  2010  Republican          STATE HOUSE/ASSEMBLY      in-state
# 16  2010  Republican          STATE HOUSE/ASSEMBLY  out-of-state
# 18  2010  Republican                  STATE SENATE      in-state
# 19  2010  Republican                  STATE SENATE  out-of-state
# 30  2014  Democratic  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 31  2014  Democratic  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 33  2014  Democratic          STATE HOUSE/ASSEMBLY      in-state
# 34  2014  Democratic          STATE HOUSE/ASSEMBLY  out-of-state
# 36  2014  Democratic                  STATE SENATE      in-state
# 37  2014  Democratic                  STATE SENATE  out-of-state
# 42  2014  Republican  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 43  2014  Republican  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 45  2014  Republican          STATE HOUSE/ASSEMBLY      in-state
# 46  2014  Republican          STATE HOUSE/ASSEMBLY  out-of-state
# 48  2014  Republican                  STATE SENATE      in-state
# 49  2014  Republican                  STATE SENATE  out-of-state
# 60  2018  Democratic  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 61  2018  Democratic  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 63  2018  Democratic          STATE HOUSE/ASSEMBLY      in-state
# 64  2018  Democratic          STATE HOUSE/ASSEMBLY  out-of-state
# 66  2018  Democratic                  STATE SENATE      in-state
# 67  2018  Democratic                  STATE SENATE  out-of-state
# 74  2018  Republican  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 75  2018  Republican  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 77  2018  Republican          STATE HOUSE/ASSEMBLY      in-state
# 78  2018  Republican          STATE HOUSE/ASSEMBLY  out-of-state
# 80  2018  Republican                  STATE SENATE      in-state
# 81  2018  Republican                  STATE SENATE  out-of-state
#
#               sum  average  median
# 0  230,772,990.78   883.76  100.00
# 1   33,055,604.70 1,135.78  250.00
# 3  151,477,797.79   376.82  100.00
# 4   15,521,314.60   459.62  250.00
# 6   88,739,830.53   447.12  150.00
# 7   10,408,953.19   604.08  400.00
# 12 448,491,319.65 1,126.97  100.00
# 13  32,663,205.26 1,111.64  250.00
# 15 122,783,382.99   367.67  100.00
# 16  10,373,473.17   454.32  250.00
# 18  77,402,598.04   454.44  150.00
# 19   6,980,604.35   562.82  500.00
# 30 193,286,784.14   629.71   50.00
# 31  42,787,001.23   532.90   50.00
# 33 144,237,818.34   402.32  100.00
# 34  18,971,767.13   493.85  250.00
# 36  73,835,181.25   449.85  100.00
# 37   9,292,575.52   294.27   25.00
# 42 205,315,120.51   649.86  100.00
# 43  49,230,848.34   489.72   50.00
# 45 153,422,814.78   465.75  200.00
# 46  15,549,233.86   553.20  500.00
# 48  99,521,354.54   608.18  250.00
# 49  10,146,947.11   716.14  500.00
# 60 428,305,926.21   958.53   50.00
# 61  56,621,009.83   353.40   25.00
# 63 151,960,126.31   363.15  100.00
# 64  26,389,191.67   373.44  100.00
# 66  89,132,513.88   417.15  100.00
# 67  13,363,576.52   342.82   50.00
# 74 461,971,654.98 1,040.20   88.63
# 75  41,265,310.34   290.12   50.00
# 77 154,267,007.84   583.19  200.00
# 78  15,738,178.18   673.67  500.00
# 80 118,109,121.82   791.73  250.00
# 81  12,025,663.89   844.20  500.00

# %% [markdown]
# Pivot dataframe to aggregate each year and office's data in a single row.

# %%
contributions_by_party_office = pd.pivot_table(contributions_by_party_office, index=["year", "standardized_office"], columns=["party", "in_out_state"]).reset_index()
contributions_by_party_office
# Out:
#               year           standardized_office    average               \
# party                                            Democratic
# in_out_state                                       in-state out-of-state
# 0             2010  GOVERNOR/LIEUTENANT GOVERNOR     883.76     1,135.78
# 1             2010          STATE HOUSE/ASSEMBLY     376.82       459.62
# 2             2010                  STATE SENATE     447.12       604.08
# 3             2014  GOVERNOR/LIEUTENANT GOVERNOR     629.71       532.90
# 4             2014          STATE HOUSE/ASSEMBLY     402.32       493.85
# 5             2014                  STATE SENATE     449.85       294.27
# 6             2018  GOVERNOR/LIEUTENANT GOVERNOR     958.53       353.40
# 7             2018          STATE HOUSE/ASSEMBLY     363.15       373.44
# 8             2018                  STATE SENATE     417.15       342.82
#
#                                          median                          \
# party        Republican              Democratic              Republican
# in_out_state   in-state out-of-state   in-state out-of-state   in-state
# 0              1,126.97     1,111.64     100.00       250.00     100.00
# 1                367.67       454.32     100.00       250.00     100.00
# 2                454.44       562.82     150.00       400.00     150.00
# 3                649.86       489.72      50.00        50.00     100.00
# 4                465.75       553.20     100.00       250.00     200.00
# 5                608.18       716.14     100.00        25.00     250.00
# 6              1,040.20       290.12      50.00        25.00      88.63
# 7                583.19       673.67     100.00       100.00     200.00
# 8                791.73       844.20     100.00        50.00     250.00
#
#                                      sum                               \
# party                         Democratic                   Republican
# in_out_state out-of-state       in-state  out-of-state       in-state
# 0                  250.00 230,772,990.78 33,055,604.70 448,491,319.65
# 1                  250.00 151,477,797.79 15,521,314.60 122,783,382.99
# 2                  500.00  88,739,830.53 10,408,953.19  77,402,598.04
# 3                   50.00 193,286,784.14 42,787,001.23 205,315,120.51
# 4                  500.00 144,237,818.34 18,971,767.13 153,422,814.78
# 5                  500.00  73,835,181.25  9,292,575.52  99,521,354.54
# 6                   50.00 428,305,926.21 56,621,009.83 461,971,654.98
# 7                  500.00 151,960,126.31 26,389,191.67 154,267,007.84
# 8                  500.00  89,132,513.88 13,363,576.52 118,109,121.82
#
#
# party
# in_out_state  out-of-state
# 0            32,663,205.26
# 1            10,373,473.17
# 2             6,980,604.35
# 3            49,230,848.34
# 4            15,549,233.86
# 5            10,146,947.11
# 6            41,265,310.34
# 7            15,738,178.18
# 8            12,025,663.89

# %% [markdown]
# Flatten the resulting dataframe's multi-index columns.

# %%
contributions_by_party_office.columns = ["year", "standardized_office",
                                  "avg_dem_in_state", "avg_dem_out_of_state",
                                  "avg_rep_in_state", "avg_rep_out_of_state",
                                  "med_dem_in_state", "med_dem_out_of_state",
                                  "med_rep_in_state", "med_rep_out_of_state",
                                  "sum_dem_in_state", "sum_dem_out_of_state",
                                  "sum_rep_in_state", "sum_rep_out_of_state"
                                  ]                          
contributions_by_party_office
# Out:
#    year           standardized_office  avg_dem_in_state  avg_dem_out_of_state  \
# 0  2010  GOVERNOR/LIEUTENANT GOVERNOR            883.76              1,135.78
# 1  2010          STATE HOUSE/ASSEMBLY            376.82                459.62
# 2  2010                  STATE SENATE            447.12                604.08
# 3  2014  GOVERNOR/LIEUTENANT GOVERNOR            629.71                532.90
# 4  2014          STATE HOUSE/ASSEMBLY            402.32                493.85
# 5  2014                  STATE SENATE            449.85                294.27
# 6  2018  GOVERNOR/LIEUTENANT GOVERNOR            958.53                353.40
# 7  2018          STATE HOUSE/ASSEMBLY            363.15                373.44
# 8  2018                  STATE SENATE            417.15                342.82
#
#    avg_rep_in_state  avg_rep_out_of_state  med_dem_in_state  \
# 0          1,126.97              1,111.64            100.00
# 1            367.67                454.32            100.00
# 2            454.44                562.82            150.00
# 3            649.86                489.72             50.00
# 4            465.75                553.20            100.00
# 5            608.18                716.14            100.00
# 6          1,040.20                290.12             50.00
# 7            583.19                673.67            100.00
# 8            791.73                844.20            100.00
#
#    med_dem_out_of_state  med_rep_in_state  med_rep_out_of_state  \
# 0                250.00            100.00                250.00
# 1                250.00            100.00                250.00
# 2                400.00            150.00                500.00
# 3                 50.00            100.00                 50.00
# 4                250.00            200.00                500.00
# 5                 25.00            250.00                500.00
# 6                 25.00             88.63                 50.00
# 7                100.00            200.00                500.00
# 8                 50.00            250.00                500.00
#
#    sum_dem_in_state  sum_dem_out_of_state  sum_rep_in_state  \
# 0    230,772,990.78         33,055,604.70    448,491,319.65
# 1    151,477,797.79         15,521,314.60    122,783,382.99
# 2     88,739,830.53         10,408,953.19     77,402,598.04
# 3    193,286,784.14         42,787,001.23    205,315,120.51
# 4    144,237,818.34         18,971,767.13    153,422,814.78
# 5     73,835,181.25          9,292,575.52     99,521,354.54
# 6    428,305,926.21         56,621,009.83    461,971,654.98
# 7    151,960,126.31         26,389,191.67    154,267,007.84
# 8     89,132,513.88         13,363,576.52    118,109,121.82
#
#    sum_rep_out_of_state
# 0         32,663,205.26
# 1         10,373,473.17
# 2          6,980,604.35
# 3         49,230,848.34
# 4         15,549,233.86
# 5         10,146,947.11
# 6         41,265,310.34
# 7         15,738,178.18
# 8         12,025,663.89

# %% [markdown]
# Calculate the difference between the parties.

# %%
contributions_by_party_office["diff_avg_in_state"] = (contributions_by_party_office["avg_rep_in_state"] - contributions_by_party_office["avg_dem_in_state"]) / contributions_by_party_office["avg_dem_in_state"]
contributions_by_party_office["diff_avg_out_of_state"] = (contributions_by_party_office["avg_rep_out_of_state"] - contributions_by_party_office["avg_dem_out_of_state"]) / contributions_by_party_office["avg_dem_out_of_state"]
contributions_by_party_office["diff_med_in_state"] = (contributions_by_party_office["med_rep_in_state"] - contributions_by_party_office["med_dem_in_state"]) / contributions_by_party_office["med_dem_in_state"]
contributions_by_party_office["diff_med_out_of_state"] = (contributions_by_party_office["med_rep_out_of_state"] - contributions_by_party_office["med_dem_out_of_state"]) / contributions_by_party_office["med_dem_out_of_state"]
contributions_by_party_office["diff_sum_in_state"] = (contributions_by_party_office["sum_rep_in_state"] - contributions_by_party_office["sum_dem_in_state"]) / contributions_by_party_office["sum_dem_in_state"]
contributions_by_party_office["diff_sum_out_of_state"] = (contributions_by_party_office["sum_rep_out_of_state"] - contributions_by_party_office["sum_dem_out_of_state"]) / contributions_by_party_office["sum_dem_out_of_state"]
contributions_by_party_office
# Out:
#    year           standardized_office  avg_dem_in_state  avg_dem_out_of_state  \
# 0  2010  GOVERNOR/LIEUTENANT GOVERNOR            883.76              1,135.78
# 1  2010          STATE HOUSE/ASSEMBLY            376.82                459.62
# 2  2010                  STATE SENATE            447.12                604.08
# 3  2014  GOVERNOR/LIEUTENANT GOVERNOR            629.71                532.90
# 4  2014          STATE HOUSE/ASSEMBLY            402.32                493.85
# 5  2014                  STATE SENATE            449.85                294.27
# 6  2018  GOVERNOR/LIEUTENANT GOVERNOR            958.53                353.40
# 7  2018          STATE HOUSE/ASSEMBLY            363.15                373.44
# 8  2018                  STATE SENATE            417.15                342.82
#
#    avg_rep_in_state  avg_rep_out_of_state  med_dem_in_state  \
# 0          1,126.97              1,111.64            100.00
# 1            367.67                454.32            100.00
# 2            454.44                562.82            150.00
# 3            649.86                489.72             50.00
# 4            465.75                553.20            100.00
# 5            608.18                716.14            100.00
# 6          1,040.20                290.12             50.00
# 7            583.19                673.67            100.00
# 8            791.73                844.20            100.00
#
#    med_dem_out_of_state  med_rep_in_state  med_rep_out_of_state  \
# 0                250.00            100.00                250.00
# 1                250.00            100.00                250.00
# 2                400.00            150.00                500.00
# 3                 50.00            100.00                 50.00
# 4                250.00            200.00                500.00
# 5                 25.00            250.00                500.00
# 6                 25.00             88.63                 50.00
# 7                100.00            200.00                500.00
# 8                 50.00            250.00                500.00
#
#    sum_dem_in_state  sum_dem_out_of_state  sum_rep_in_state  \
# 0    230,772,990.78         33,055,604.70    448,491,319.65
# 1    151,477,797.79         15,521,314.60    122,783,382.99
# 2     88,739,830.53         10,408,953.19     77,402,598.04
# 3    193,286,784.14         42,787,001.23    205,315,120.51
# 4    144,237,818.34         18,971,767.13    153,422,814.78
# 5     73,835,181.25          9,292,575.52     99,521,354.54
# 6    428,305,926.21         56,621,009.83    461,971,654.98
# 7    151,960,126.31         26,389,191.67    154,267,007.84
# 8     89,132,513.88         13,363,576.52    118,109,121.82
#
#    sum_rep_out_of_state  diff_avg_in_state  diff_avg_out_of_state  \
# 0         32,663,205.26               0.28                  -0.02
# 1         10,373,473.17              -0.02                  -0.01
# 2          6,980,604.35               0.02                  -0.07
# 3         49,230,848.34               0.03                  -0.08
# 4         15,549,233.86               0.16                   0.12
# 5         10,146,947.11               0.35                   1.43
# 6         41,265,310.34               0.09                  -0.18
# 7         15,738,178.18               0.61                   0.80
# 8         12,025,663.89               0.90                   1.46
#
#    diff_med_in_state  diff_med_out_of_state  diff_sum_in_state  \
# 0               0.00                   0.00               0.94
# 1               0.00                   0.00              -0.19
# 2               0.00                   0.25              -0.13
# 3               1.00                   0.00               0.06
# 4               1.00                   1.00               0.06
# 5               1.50                  19.00               0.35
# 6               0.77                   1.00               0.08
# 7               1.00                   4.00               0.02
# 8               1.50                   9.00               0.33
#
#    diff_sum_out_of_state
# 0                  -0.01
# 1                  -0.33
# 2                  -0.33
# 3                   0.15
# 4                  -0.18
# 5                   0.09
# 6                  -0.27
# 7                  -0.40
# 8                  -0.10

# %% [markdown]
# Rearrange the columns.

# %%
contributions_by_party_office = contributions_by_party_office[["year", "standardized_office",
                                  "avg_dem_in_state", "avg_rep_in_state", "diff_avg_in_state",
                                  "avg_dem_out_of_state", "avg_rep_out_of_state", "diff_avg_out_of_state",
                                  "med_dem_in_state", "med_rep_in_state", "diff_med_in_state",
                                  "med_dem_out_of_state", "med_rep_out_of_state", "diff_med_out_of_state",
                                  "sum_dem_in_state", "sum_rep_in_state", "diff_sum_in_state",
                                  "sum_dem_out_of_state", "sum_rep_out_of_state", "diff_sum_out_of_state"]]
contributions_by_party_office
# Out:
#    year           standardized_office  avg_dem_in_state  avg_rep_in_state  \
# 0  2010  GOVERNOR/LIEUTENANT GOVERNOR            883.76          1,126.97
# 1  2010          STATE HOUSE/ASSEMBLY            376.82            367.67
# 2  2010                  STATE SENATE            447.12            454.44
# 3  2014  GOVERNOR/LIEUTENANT GOVERNOR            629.71            649.86
# 4  2014          STATE HOUSE/ASSEMBLY            402.32            465.75
# 5  2014                  STATE SENATE            449.85            608.18
# 6  2018  GOVERNOR/LIEUTENANT GOVERNOR            958.53          1,040.20
# 7  2018          STATE HOUSE/ASSEMBLY            363.15            583.19
# 8  2018                  STATE SENATE            417.15            791.73
#
#    diff_avg_in_state  avg_dem_out_of_state  avg_rep_out_of_state  \
# 0               0.28              1,135.78              1,111.64
# 1              -0.02                459.62                454.32
# 2               0.02                604.08                562.82
# 3               0.03                532.90                489.72
# 4               0.16                493.85                553.20
# 5               0.35                294.27                716.14
# 6               0.09                353.40                290.12
# 7               0.61                373.44                673.67
# 8               0.90                342.82                844.20
#
#    diff_avg_out_of_state  med_dem_in_state  med_rep_in_state  \
# 0                  -0.02            100.00            100.00
# 1                  -0.01            100.00            100.00
# 2                  -0.07            150.00            150.00
# 3                  -0.08             50.00            100.00
# 4                   0.12            100.00            200.00
# 5                   1.43            100.00            250.00
# 6                  -0.18             50.00             88.63
# 7                   0.80            100.00            200.00
# 8                   1.46            100.00            250.00
#
#    diff_med_in_state  med_dem_out_of_state  med_rep_out_of_state  \
# 0               0.00                250.00                250.00
# 1               0.00                250.00                250.00
# 2               0.00                400.00                500.00
# 3               1.00                 50.00                 50.00
# 4               1.00                250.00                500.00
# 5               1.50                 25.00                500.00
# 6               0.77                 25.00                 50.00
# 7               1.00                100.00                500.00
# 8               1.50                 50.00                500.00
#
#    diff_med_out_of_state  sum_dem_in_state  sum_rep_in_state  \
# 0                   0.00    230,772,990.78    448,491,319.65
# 1                   0.00    151,477,797.79    122,783,382.99
# 2                   0.25     88,739,830.53     77,402,598.04
# 3                   0.00    193,286,784.14    205,315,120.51
# 4                   1.00    144,237,818.34    153,422,814.78
# 5                  19.00     73,835,181.25     99,521,354.54
# 6                   1.00    428,305,926.21    461,971,654.98
# 7                   4.00    151,960,126.31    154,267,007.84
# 8                   9.00     89,132,513.88    118,109,121.82
#
#    diff_sum_in_state  sum_dem_out_of_state  sum_rep_out_of_state  \
# 0               0.94         33,055,604.70         32,663,205.26
# 1              -0.19         15,521,314.60         10,373,473.17
# 2              -0.13         10,408,953.19          6,980,604.35
# 3               0.06         42,787,001.23         49,230,848.34
# 4               0.06         18,971,767.13         15,549,233.86
# 5               0.35          9,292,575.52         10,146,947.11
# 6               0.08         56,621,009.83         41,265,310.34
# 7               0.02         26,389,191.67         15,738,178.18
# 8               0.33         13,363,576.52         12,025,663.89
#
#    diff_sum_out_of_state
# 0                  -0.01
# 1                  -0.33
# 2                  -0.33
# 3                   0.15
# 4                  -0.18
# 5                   0.09
# 6                  -0.27
# 7                  -0.40
# 8                  -0.10

# %% [markdown]
# ## Is there a difference in the average out-of-state contributor to Democratic vs. Republican candidates?

# %% [markdown]
# First, group the data by contributor.

# %%
contributors = contributions.groupby(["year", "party", "standardized_office", "in_out_state", "contributor"])["amount"].sum().reset_index()
contributors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3709704 entries, 0 to 3709703
# Data columns (total 6 columns):
# year                   int64
# party                  object
# standardized_office    object
# in_out_state           object
# contributor            object
# amount                 float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 169.8+ MB

# %% [markdown]
# Then group by year, party, office and in-vs.-out-of-state contribution status and calculate the total contributions, average contributions and median contributions per group.

# %%
contributors_by_party_office = contributors.groupby(["year", "party", "standardized_office", "in_out_state"])["amount"].agg([sum, np.average, "median"]).reset_index()
contributors_by_party_office
# Out:
#     year        party           standardized_office  in_out_state  \
# 0   2010   Democratic  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 1   2010   Democratic  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 2   2010   Democratic  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 3   2010   Democratic          STATE HOUSE/ASSEMBLY      in-state
# 4   2010   Democratic          STATE HOUSE/ASSEMBLY  out-of-state
# 5   2010   Democratic          STATE HOUSE/ASSEMBLY       unknown
# 6   2010   Democratic                  STATE SENATE      in-state
# 7   2010   Democratic                  STATE SENATE  out-of-state
# 8   2010   Democratic                  STATE SENATE       unknown
# 9   2010  Nonpartisan                  STATE SENATE      in-state
# 10  2010  Nonpartisan                  STATE SENATE  out-of-state
# 11  2010  Nonpartisan                  STATE SENATE       unknown
# 12  2010   Republican  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 13  2010   Republican  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 14  2010   Republican  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 15  2010   Republican          STATE HOUSE/ASSEMBLY      in-state
# 16  2010   Republican          STATE HOUSE/ASSEMBLY  out-of-state
# 17  2010   Republican          STATE HOUSE/ASSEMBLY       unknown
# 18  2010   Republican                  STATE SENATE      in-state
# 19  2010   Republican                  STATE SENATE  out-of-state
# 20  2010   Republican                  STATE SENATE       unknown
# 21  2010  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 22  2010  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 23  2010  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 24  2010  Third-Party          STATE HOUSE/ASSEMBLY      in-state
# 25  2010  Third-Party          STATE HOUSE/ASSEMBLY  out-of-state
# 26  2010  Third-Party          STATE HOUSE/ASSEMBLY       unknown
# 27  2010  Third-Party                  STATE SENATE      in-state
# 28  2010  Third-Party                  STATE SENATE  out-of-state
# 29  2010  Third-Party                  STATE SENATE       unknown
# 30  2014   Democratic  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 31  2014   Democratic  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 32  2014   Democratic  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 33  2014   Democratic          STATE HOUSE/ASSEMBLY      in-state
# 34  2014   Democratic          STATE HOUSE/ASSEMBLY  out-of-state
# 35  2014   Democratic          STATE HOUSE/ASSEMBLY       unknown
# 36  2014   Democratic                  STATE SENATE      in-state
# 37  2014   Democratic                  STATE SENATE  out-of-state
# 38  2014   Democratic                  STATE SENATE       unknown
# 39  2014  Nonpartisan                  STATE SENATE      in-state
# 40  2014  Nonpartisan                  STATE SENATE  out-of-state
# 41  2014  Nonpartisan                  STATE SENATE       unknown
# 42  2014   Republican  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 43  2014   Republican  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 44  2014   Republican  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 45  2014   Republican          STATE HOUSE/ASSEMBLY      in-state
# 46  2014   Republican          STATE HOUSE/ASSEMBLY  out-of-state
# 47  2014   Republican          STATE HOUSE/ASSEMBLY       unknown
# 48  2014   Republican                  STATE SENATE      in-state
# 49  2014   Republican                  STATE SENATE  out-of-state
# 50  2014   Republican                  STATE SENATE       unknown
# 51  2014  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 52  2014  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 53  2014  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 54  2014  Third-Party          STATE HOUSE/ASSEMBLY      in-state
# 55  2014  Third-Party          STATE HOUSE/ASSEMBLY  out-of-state
# 56  2014  Third-Party          STATE HOUSE/ASSEMBLY       unknown
# 57  2014  Third-Party                  STATE SENATE      in-state
# 58  2014  Third-Party                  STATE SENATE  out-of-state
# 59  2014  Third-Party                  STATE SENATE       unknown
# 60  2018   Democratic  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 61  2018   Democratic  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 62  2018   Democratic  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 63  2018   Democratic          STATE HOUSE/ASSEMBLY      in-state
# 64  2018   Democratic          STATE HOUSE/ASSEMBLY  out-of-state
# 65  2018   Democratic          STATE HOUSE/ASSEMBLY       unknown
# 66  2018   Democratic                  STATE SENATE      in-state
# 67  2018   Democratic                  STATE SENATE  out-of-state
# 68  2018   Democratic                  STATE SENATE       unknown
# 69  2018  Nonpartisan          STATE HOUSE/ASSEMBLY      in-state
# 70  2018  Nonpartisan          STATE HOUSE/ASSEMBLY  out-of-state
# 71  2018  Nonpartisan                  STATE SENATE      in-state
# 72  2018  Nonpartisan                  STATE SENATE  out-of-state
# 73  2018  Nonpartisan                  STATE SENATE       unknown
# 74  2018   Republican  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 75  2018   Republican  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 76  2018   Republican  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 77  2018   Republican          STATE HOUSE/ASSEMBLY      in-state
# 78  2018   Republican          STATE HOUSE/ASSEMBLY  out-of-state
# 79  2018   Republican          STATE HOUSE/ASSEMBLY       unknown
# 80  2018   Republican                  STATE SENATE      in-state
# 81  2018   Republican                  STATE SENATE  out-of-state
# 82  2018   Republican                  STATE SENATE       unknown
# 83  2018  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 84  2018  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 85  2018  Third-Party  GOVERNOR/LIEUTENANT GOVERNOR       unknown
# 86  2018  Third-Party          STATE HOUSE/ASSEMBLY      in-state
# 87  2018  Third-Party          STATE HOUSE/ASSEMBLY  out-of-state
# 88  2018  Third-Party          STATE HOUSE/ASSEMBLY       unknown
# 89  2018  Third-Party                  STATE SENATE      in-state
# 90  2018  Third-Party                  STATE SENATE  out-of-state
# 91  2018  Third-Party                  STATE SENATE       unknown
# 92  2018      Unknown  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 93  2018      Unknown  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
#
#               sum   average   median
# 0  230,772,990.78  1,296.96   200.00
# 1   33,055,604.70  1,529.43   250.00
# 2      330,443.83    595.39   237.00
# 3  151,477,797.79    678.12   100.00
# 4   15,521,314.60    891.31   100.00
# 5      704,006.80    381.99   100.00
# 6   88,739,830.53    745.97   125.00
# 7   10,408,703.19  1,252.55   200.00
# 8      524,722.16    466.42   100.00
# 9      941,726.00  2,446.04   500.00
# 10     136,753.70  2,072.03 1,000.00
# 11     -19,688.72 -1,514.52  -500.00
# 12 448,491,144.65  1,717.06   125.00
# 13  32,663,205.26  1,448.61   250.00
# 14     237,444.43    648.76   100.00
# 15 122,783,382.99    594.99   100.00
# 16  10,373,473.17    998.70   150.00
# 17     284,294.94    354.93   100.00
# 18  77,402,598.04    738.84   150.00
# 19   6,980,554.35  1,391.94   250.00
# 20     243,554.77    333.64   103.49
# 21   3,172,624.04    522.41   200.00
# 22     377,656.73    376.15   250.00
# 23   1,538,273.15 27,469.16   100.00
# 24   1,532,088.03    366.97   100.00
# 25     123,681.19    332.48   100.00
# 26       9,417.30    235.43   100.00
# 27   1,482,390.78    775.31   200.00
# 28     152,426.10  1,096.59   390.59
# 29     -10,803.82   -327.39    20.00
# 30 193,286,784.14  1,097.24   100.00
# 31  42,787,001.23    859.82   100.00
# 32   1,766,363.37    344.19   200.00
# 33 144,237,818.34    702.11   100.00
# 34  18,971,767.13    919.89   100.00
# 35   2,587,939.20    272.96   100.00
# 36  73,835,181.25    721.05   100.00
# 37   9,292,575.52    444.98    10.00
# 38   1,688,927.72    371.27   125.00
# 39   1,617,096.45  1,330.94   500.00
# 40     156,743.05  1,205.72   500.00
# 41       4,068.00    581.14   500.00
# 42 205,315,120.51  1,051.17   100.00
# 43  49,230,848.34    847.67    75.00
# 44   8,453,990.94  2,446.89    70.00
# 45 153,422,814.78    804.92   150.00
# 46  15,549,233.86  1,438.55   200.00
# 47   2,066,869.19    726.49   100.00
# 48  99,521,354.54  1,050.20   200.00
# 49  10,146,947.11  2,258.89   400.00
# 50     473,948.59    596.16   200.00
# 51   8,609,356.65  1,988.30   125.00
# 52     374,487.09    450.10   250.00
# 53      19,805.96    638.90    50.00
# 54   1,869,669.62    490.86   100.00
# 55     134,931.14    282.28   100.00
# 56       2,014.62    167.88    89.25
# 57   1,762,007.65    897.61   150.00
# 58     108,934.58    482.01   100.00
# 59      15,343.18    958.95   500.00
# 60 428,305,406.21  1,962.57   100.00
# 61  56,620,937.15    634.97    50.00
# 62   3,194,401.76  2,409.05    50.00
# 63 151,959,613.31    646.82   100.00
# 64  26,388,572.67    606.73   100.00
# 65   4,305,122.43    381.66   110.00
# 66  89,132,513.88    710.01   100.00
# 67  13,363,096.52    601.05    50.00
# 68   2,675,072.96    450.12   125.00
# 69       2,897.59    222.89   200.00
# 70         350.00    350.00   350.00
# 71   1,373,439.74  1,625.37   500.00
# 72     310,156.30  2,794.20 1,000.00
# 73      -3,156.23   -394.53   375.00
# 74 461,971,354.98  1,974.27   150.00
# 75  41,265,310.34    498.67    75.00
# 76   3,978,262.22  4,362.13   250.00
# 77 154,266,582.84    995.07   150.00
# 78  15,738,178.18  1,784.78   250.00
# 79   3,295,232.06    524.47   200.00
# 80 118,109,071.82  1,372.42   200.00
# 81  12,025,663.89  2,614.84   400.00
# 82   1,898,861.56    648.30   250.00
# 83   3,001,405.04    632.67   100.00
# 84     252,867.21    263.95   100.00
# 85     518,202.42  5,454.76    50.00
# 86     638,528.03    307.58   100.00
# 87     121,910.20    245.29    75.00
# 88      28,195.91  2,013.99   355.00
# 89     176,643.05    466.08   100.00
# 90      25,016.19    142.14   100.00
# 91      15,845.00  2,640.83   110.00
# 92      28,042.01    778.94   500.00
# 93       7,944.09    882.68   750.00

# %% [markdown]
# Drop non-major parties and unknown contribution statuses.

# %%
contributors_by_party_office = contributors_by_party_office[((contributors_by_party_office["party"] == "Democratic") | (contributors_by_party_office["party"] == "Republican")) & (contributors_by_party_office["in_out_state"] != "unknown")]
contributors_by_party_office
# Out:
#     year       party           standardized_office  in_out_state  \
# 0   2010  Democratic  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 1   2010  Democratic  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 3   2010  Democratic          STATE HOUSE/ASSEMBLY      in-state
# 4   2010  Democratic          STATE HOUSE/ASSEMBLY  out-of-state
# 6   2010  Democratic                  STATE SENATE      in-state
# 7   2010  Democratic                  STATE SENATE  out-of-state
# 12  2010  Republican  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 13  2010  Republican  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 15  2010  Republican          STATE HOUSE/ASSEMBLY      in-state
# 16  2010  Republican          STATE HOUSE/ASSEMBLY  out-of-state
# 18  2010  Republican                  STATE SENATE      in-state
# 19  2010  Republican                  STATE SENATE  out-of-state
# 30  2014  Democratic  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 31  2014  Democratic  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 33  2014  Democratic          STATE HOUSE/ASSEMBLY      in-state
# 34  2014  Democratic          STATE HOUSE/ASSEMBLY  out-of-state
# 36  2014  Democratic                  STATE SENATE      in-state
# 37  2014  Democratic                  STATE SENATE  out-of-state
# 42  2014  Republican  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 43  2014  Republican  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 45  2014  Republican          STATE HOUSE/ASSEMBLY      in-state
# 46  2014  Republican          STATE HOUSE/ASSEMBLY  out-of-state
# 48  2014  Republican                  STATE SENATE      in-state
# 49  2014  Republican                  STATE SENATE  out-of-state
# 60  2018  Democratic  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 61  2018  Democratic  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 63  2018  Democratic          STATE HOUSE/ASSEMBLY      in-state
# 64  2018  Democratic          STATE HOUSE/ASSEMBLY  out-of-state
# 66  2018  Democratic                  STATE SENATE      in-state
# 67  2018  Democratic                  STATE SENATE  out-of-state
# 74  2018  Republican  GOVERNOR/LIEUTENANT GOVERNOR      in-state
# 75  2018  Republican  GOVERNOR/LIEUTENANT GOVERNOR  out-of-state
# 77  2018  Republican          STATE HOUSE/ASSEMBLY      in-state
# 78  2018  Republican          STATE HOUSE/ASSEMBLY  out-of-state
# 80  2018  Republican                  STATE SENATE      in-state
# 81  2018  Republican                  STATE SENATE  out-of-state
#
#               sum  average  median
# 0  230,772,990.78 1,296.96  200.00
# 1   33,055,604.70 1,529.43  250.00
# 3  151,477,797.79   678.12  100.00
# 4   15,521,314.60   891.31  100.00
# 6   88,739,830.53   745.97  125.00
# 7   10,408,703.19 1,252.55  200.00
# 12 448,491,144.65 1,717.06  125.00
# 13  32,663,205.26 1,448.61  250.00
# 15 122,783,382.99   594.99  100.00
# 16  10,373,473.17   998.70  150.00
# 18  77,402,598.04   738.84  150.00
# 19   6,980,554.35 1,391.94  250.00
# 30 193,286,784.14 1,097.24  100.00
# 31  42,787,001.23   859.82  100.00
# 33 144,237,818.34   702.11  100.00
# 34  18,971,767.13   919.89  100.00
# 36  73,835,181.25   721.05  100.00
# 37   9,292,575.52   444.98   10.00
# 42 205,315,120.51 1,051.17  100.00
# 43  49,230,848.34   847.67   75.00
# 45 153,422,814.78   804.92  150.00
# 46  15,549,233.86 1,438.55  200.00
# 48  99,521,354.54 1,050.20  200.00
# 49  10,146,947.11 2,258.89  400.00
# 60 428,305,406.21 1,962.57  100.00
# 61  56,620,937.15   634.97   50.00
# 63 151,959,613.31   646.82  100.00
# 64  26,388,572.67   606.73  100.00
# 66  89,132,513.88   710.01  100.00
# 67  13,363,096.52   601.05   50.00
# 74 461,971,354.98 1,974.27  150.00
# 75  41,265,310.34   498.67   75.00
# 77 154,266,582.84   995.07  150.00
# 78  15,738,178.18 1,784.78  250.00
# 80 118,109,071.82 1,372.42  200.00
# 81  12,025,663.89 2,614.84  400.00

# %% [markdown]
# Pivot dataframe to aggregate each year and office's data in a single row.

# %%
contributors_by_party_office = pd.pivot_table(contributors_by_party_office, index=["year", "standardized_office"], columns=["party", "in_out_state"]).reset_index()
contributors_by_party_office
# Out:
#               year           standardized_office    average               \
# party                                            Democratic
# in_out_state                                       in-state out-of-state
# 0             2010  GOVERNOR/LIEUTENANT GOVERNOR   1,296.96     1,529.43
# 1             2010          STATE HOUSE/ASSEMBLY     678.12       891.31
# 2             2010                  STATE SENATE     745.97     1,252.55
# 3             2014  GOVERNOR/LIEUTENANT GOVERNOR   1,097.24       859.82
# 4             2014          STATE HOUSE/ASSEMBLY     702.11       919.89
# 5             2014                  STATE SENATE     721.05       444.98
# 6             2018  GOVERNOR/LIEUTENANT GOVERNOR   1,962.57       634.97
# 7             2018          STATE HOUSE/ASSEMBLY     646.82       606.73
# 8             2018                  STATE SENATE     710.01       601.05
#
#                                          median                          \
# party        Republican              Democratic              Republican
# in_out_state   in-state out-of-state   in-state out-of-state   in-state
# 0              1,717.06     1,448.61     200.00       250.00     125.00
# 1                594.99       998.70     100.00       100.00     100.00
# 2                738.84     1,391.94     125.00       200.00     150.00
# 3              1,051.17       847.67     100.00       100.00     100.00
# 4                804.92     1,438.55     100.00       100.00     150.00
# 5              1,050.20     2,258.89     100.00        10.00     200.00
# 6              1,974.27       498.67     100.00        50.00     150.00
# 7                995.07     1,784.78     100.00       100.00     150.00
# 8              1,372.42     2,614.84     100.00        50.00     200.00
#
#                                      sum                               \
# party                         Democratic                   Republican
# in_out_state out-of-state       in-state  out-of-state       in-state
# 0                  250.00 230,772,990.78 33,055,604.70 448,491,144.65
# 1                  150.00 151,477,797.79 15,521,314.60 122,783,382.99
# 2                  250.00  88,739,830.53 10,408,703.19  77,402,598.04
# 3                   75.00 193,286,784.14 42,787,001.23 205,315,120.51
# 4                  200.00 144,237,818.34 18,971,767.13 153,422,814.78
# 5                  400.00  73,835,181.25  9,292,575.52  99,521,354.54
# 6                   75.00 428,305,406.21 56,620,937.15 461,971,354.98
# 7                  250.00 151,959,613.31 26,388,572.67 154,266,582.84
# 8                  400.00  89,132,513.88 13,363,096.52 118,109,071.82
#
#
# party
# in_out_state  out-of-state
# 0            32,663,205.26
# 1            10,373,473.17
# 2             6,980,554.35
# 3            49,230,848.34
# 4            15,549,233.86
# 5            10,146,947.11
# 6            41,265,310.34
# 7            15,738,178.18
# 8            12,025,663.89

# %% [markdown]
# Flatten the resulting dataframe's multi-index columns.

# %%
contributors_by_party_office.columns = ["year", "standardized_office",
                                  "avg_dem_in_state", "avg_dem_out_of_state",
                                  "avg_rep_in_state", "avg_rep_out_of_state",
                                  "med_dem_in_state", "med_dem_out_of_state",
                                  "med_rep_in_state", "med_rep_out_of_state",
                                  "sum_dem_in_state", "sum_dem_out_of_state",
                                  "sum_rep_in_state", "sum_rep_out_of_state"
                                  ]
contributors_by_party_office
# Out:
#    year           standardized_office  avg_dem_in_state  avg_dem_out_of_state  \
# 0  2010  GOVERNOR/LIEUTENANT GOVERNOR          1,296.96              1,529.43
# 1  2010          STATE HOUSE/ASSEMBLY            678.12                891.31
# 2  2010                  STATE SENATE            745.97              1,252.55
# 3  2014  GOVERNOR/LIEUTENANT GOVERNOR          1,097.24                859.82
# 4  2014          STATE HOUSE/ASSEMBLY            702.11                919.89
# 5  2014                  STATE SENATE            721.05                444.98
# 6  2018  GOVERNOR/LIEUTENANT GOVERNOR          1,962.57                634.97
# 7  2018          STATE HOUSE/ASSEMBLY            646.82                606.73
# 8  2018                  STATE SENATE            710.01                601.05
#
#    avg_rep_in_state  avg_rep_out_of_state  med_dem_in_state  \
# 0          1,717.06              1,448.61            200.00
# 1            594.99                998.70            100.00
# 2            738.84              1,391.94            125.00
# 3          1,051.17                847.67            100.00
# 4            804.92              1,438.55            100.00
# 5          1,050.20              2,258.89            100.00
# 6          1,974.27                498.67            100.00
# 7            995.07              1,784.78            100.00
# 8          1,372.42              2,614.84            100.00
#
#    med_dem_out_of_state  med_rep_in_state  med_rep_out_of_state  \
# 0                250.00            125.00                250.00
# 1                100.00            100.00                150.00
# 2                200.00            150.00                250.00
# 3                100.00            100.00                 75.00
# 4                100.00            150.00                200.00
# 5                 10.00            200.00                400.00
# 6                 50.00            150.00                 75.00
# 7                100.00            150.00                250.00
# 8                 50.00            200.00                400.00
#
#    sum_dem_in_state  sum_dem_out_of_state  sum_rep_in_state  \
# 0    230,772,990.78         33,055,604.70    448,491,144.65
# 1    151,477,797.79         15,521,314.60    122,783,382.99
# 2     88,739,830.53         10,408,703.19     77,402,598.04
# 3    193,286,784.14         42,787,001.23    205,315,120.51
# 4    144,237,818.34         18,971,767.13    153,422,814.78
# 5     73,835,181.25          9,292,575.52     99,521,354.54
# 6    428,305,406.21         56,620,937.15    461,971,354.98
# 7    151,959,613.31         26,388,572.67    154,266,582.84
# 8     89,132,513.88         13,363,096.52    118,109,071.82
#
#    sum_rep_out_of_state
# 0         32,663,205.26
# 1         10,373,473.17
# 2          6,980,554.35
# 3         49,230,848.34
# 4         15,549,233.86
# 5         10,146,947.11
# 6         41,265,310.34
# 7         15,738,178.18
# 8         12,025,663.89

# %% [markdown]
# Calculate the difference between the parties.

# %%
contributors_by_party_office["diff_avg_in_state"] = (contributors_by_party_office["avg_rep_in_state"] - contributors_by_party_office["avg_dem_in_state"]) / contributors_by_party_office["avg_dem_in_state"]
contributors_by_party_office["diff_avg_out_of_state"] = (contributors_by_party_office["avg_rep_out_of_state"] - contributors_by_party_office["avg_dem_out_of_state"]) / contributors_by_party_office["avg_dem_out_of_state"]
contributors_by_party_office["diff_med_in_state"] = (contributors_by_party_office["med_rep_in_state"] - contributors_by_party_office["med_dem_in_state"]) / contributors_by_party_office["med_dem_in_state"]
contributors_by_party_office["diff_med_out_of_state"] = (contributors_by_party_office["med_rep_out_of_state"] - contributors_by_party_office["med_dem_out_of_state"]) / contributors_by_party_office["med_dem_out_of_state"]
contributors_by_party_office["diff_sum_in_state"] = (contributors_by_party_office["sum_rep_in_state"] - contributors_by_party_office["sum_dem_in_state"]) / contributors_by_party_office["sum_dem_in_state"]
contributors_by_party_office["diff_sum_out_of_state"] = (contributors_by_party_office["sum_rep_out_of_state"] - contributors_by_party_office["sum_dem_out_of_state"]) / contributors_by_party_office["sum_dem_out_of_state"]
contributors_by_party_office
# Out:
#    year           standardized_office  avg_dem_in_state  avg_dem_out_of_state  \
# 0  2010  GOVERNOR/LIEUTENANT GOVERNOR          1,296.96              1,529.43
# 1  2010          STATE HOUSE/ASSEMBLY            678.12                891.31
# 2  2010                  STATE SENATE            745.97              1,252.55
# 3  2014  GOVERNOR/LIEUTENANT GOVERNOR          1,097.24                859.82
# 4  2014          STATE HOUSE/ASSEMBLY            702.11                919.89
# 5  2014                  STATE SENATE            721.05                444.98
# 6  2018  GOVERNOR/LIEUTENANT GOVERNOR          1,962.57                634.97
# 7  2018          STATE HOUSE/ASSEMBLY            646.82                606.73
# 8  2018                  STATE SENATE            710.01                601.05
#
#    avg_rep_in_state  avg_rep_out_of_state  med_dem_in_state  \
# 0          1,717.06              1,448.61            200.00
# 1            594.99                998.70            100.00
# 2            738.84              1,391.94            125.00
# 3          1,051.17                847.67            100.00
# 4            804.92              1,438.55            100.00
# 5          1,050.20              2,258.89            100.00
# 6          1,974.27                498.67            100.00
# 7            995.07              1,784.78            100.00
# 8          1,372.42              2,614.84            100.00
#
#    med_dem_out_of_state  med_rep_in_state  med_rep_out_of_state  \
# 0                250.00            125.00                250.00
# 1                100.00            100.00                150.00
# 2                200.00            150.00                250.00
# 3                100.00            100.00                 75.00
# 4                100.00            150.00                200.00
# 5                 10.00            200.00                400.00
# 6                 50.00            150.00                 75.00
# 7                100.00            150.00                250.00
# 8                 50.00            200.00                400.00
#
#    sum_dem_in_state  sum_dem_out_of_state  sum_rep_in_state  \
# 0    230,772,990.78         33,055,604.70    448,491,144.65
# 1    151,477,797.79         15,521,314.60    122,783,382.99
# 2     88,739,830.53         10,408,703.19     77,402,598.04
# 3    193,286,784.14         42,787,001.23    205,315,120.51
# 4    144,237,818.34         18,971,767.13    153,422,814.78
# 5     73,835,181.25          9,292,575.52     99,521,354.54
# 6    428,305,406.21         56,620,937.15    461,971,354.98
# 7    151,959,613.31         26,388,572.67    154,266,582.84
# 8     89,132,513.88         13,363,096.52    118,109,071.82
#
#    sum_rep_out_of_state  diff_avg_in_state  diff_avg_out_of_state  \
# 0         32,663,205.26               0.32                  -0.05
# 1         10,373,473.17              -0.12                   0.12
# 2          6,980,554.35              -0.01                   0.11
# 3         49,230,848.34              -0.04                  -0.01
# 4         15,549,233.86               0.15                   0.56
# 5         10,146,947.11               0.46                   4.08
# 6         41,265,310.34               0.01                  -0.21
# 7         15,738,178.18               0.54                   1.94
# 8         12,025,663.89               0.93                   3.35
#
#    diff_med_in_state  diff_med_out_of_state  diff_sum_in_state  \
# 0              -0.38                   0.00               0.94
# 1               0.00                   0.50              -0.19
# 2               0.20                   0.25              -0.13
# 3               0.00                  -0.25               0.06
# 4               0.50                   1.00               0.06
# 5               1.00                  39.00               0.35
# 6               0.50                   0.50               0.08
# 7               0.50                   1.50               0.02
# 8               1.00                   7.00               0.33
#
#    diff_sum_out_of_state
# 0                  -0.01
# 1                  -0.33
# 2                  -0.33
# 3                   0.15
# 4                  -0.18
# 5                   0.09
# 6                  -0.27
# 7                  -0.40
# 8                  -0.10

# %% [markdown]
# Rearrange the columns.

# %%
contributors_by_party_office = contributors_by_party_office[["year", "standardized_office",
                                  "avg_dem_in_state", "avg_rep_in_state", "diff_avg_in_state",
                                  "avg_dem_out_of_state", "avg_rep_out_of_state", "diff_avg_out_of_state",
                                  "med_dem_in_state", "med_rep_in_state", "diff_med_in_state",
                                  "med_dem_out_of_state", "med_rep_out_of_state", "diff_med_out_of_state",
                                  "sum_dem_in_state", "sum_rep_in_state", "diff_sum_in_state",
                                  "sum_dem_out_of_state", "sum_rep_out_of_state", "diff_sum_out_of_state"]]
contributors_by_party_office
# Out:
#    year           standardized_office  avg_dem_in_state  avg_rep_in_state  \
# 0  2010  GOVERNOR/LIEUTENANT GOVERNOR          1,296.96          1,717.06
# 1  2010          STATE HOUSE/ASSEMBLY            678.12            594.99
# 2  2010                  STATE SENATE            745.97            738.84
# 3  2014  GOVERNOR/LIEUTENANT GOVERNOR          1,097.24          1,051.17
# 4  2014          STATE HOUSE/ASSEMBLY            702.11            804.92
# 5  2014                  STATE SENATE            721.05          1,050.20
# 6  2018  GOVERNOR/LIEUTENANT GOVERNOR          1,962.57          1,974.27
# 7  2018          STATE HOUSE/ASSEMBLY            646.82            995.07
# 8  2018                  STATE SENATE            710.01          1,372.42
#
#    diff_avg_in_state  avg_dem_out_of_state  avg_rep_out_of_state  \
# 0               0.32              1,529.43              1,448.61
# 1              -0.12                891.31                998.70
# 2              -0.01              1,252.55              1,391.94
# 3              -0.04                859.82                847.67
# 4               0.15                919.89              1,438.55
# 5               0.46                444.98              2,258.89
# 6               0.01                634.97                498.67
# 7               0.54                606.73              1,784.78
# 8               0.93                601.05              2,614.84
#
#    diff_avg_out_of_state  med_dem_in_state  med_rep_in_state  \
# 0                  -0.05            200.00            125.00
# 1                   0.12            100.00            100.00
# 2                   0.11            125.00            150.00
# 3                  -0.01            100.00            100.00
# 4                   0.56            100.00            150.00
# 5                   4.08            100.00            200.00
# 6                  -0.21            100.00            150.00
# 7                   1.94            100.00            150.00
# 8                   3.35            100.00            200.00
#
#    diff_med_in_state  med_dem_out_of_state  med_rep_out_of_state  \
# 0              -0.38                250.00                250.00
# 1               0.00                100.00                150.00
# 2               0.20                200.00                250.00
# 3               0.00                100.00                 75.00
# 4               0.50                100.00                200.00
# 5               1.00                 10.00                400.00
# 6               0.50                 50.00                 75.00
# 7               0.50                100.00                250.00
# 8               1.00                 50.00                400.00
#
#    diff_med_out_of_state  sum_dem_in_state  sum_rep_in_state  \
# 0                   0.00    230,772,990.78    448,491,144.65
# 1                   0.50    151,477,797.79    122,783,382.99
# 2                   0.25     88,739,830.53     77,402,598.04
# 3                  -0.25    193,286,784.14    205,315,120.51
# 4                   1.00    144,237,818.34    153,422,814.78
# 5                  39.00     73,835,181.25     99,521,354.54
# 6                   0.50    428,305,406.21    461,971,354.98
# 7                   1.50    151,959,613.31    154,266,582.84
# 8                   7.00     89,132,513.88    118,109,071.82
#
#    diff_sum_in_state  sum_dem_out_of_state  sum_rep_out_of_state  \
# 0               0.94         33,055,604.70         32,663,205.26
# 1              -0.19         15,521,314.60         10,373,473.17
# 2              -0.13         10,408,703.19          6,980,554.35
# 3               0.06         42,787,001.23         49,230,848.34
# 4               0.06         18,971,767.13         15,549,233.86
# 5               0.35          9,292,575.52         10,146,947.11
# 6               0.08         56,620,937.15         41,265,310.34
# 7               0.02         26,388,572.67         15,738,178.18
# 8               0.33         13,363,096.52         12,025,663.89
#
#    diff_sum_out_of_state
# 0                  -0.01
# 1                  -0.33
# 2                  -0.33
# 3                   0.15
# 4                  -0.18
# 5                   0.09
# 6                  -0.27
# 7                  -0.40
# 8                  -0.10

# %% [markdown]
# ## Export the data

# %%
# %%notify
# writer = pd.ExcelWriter("data/contributors_analysis.xlsx")
# contributions_by_party_office.to_excel(writer, "contributions_by_party_office", index=False)
# contributors_by_party_office.to_excel(writer, "contributors_by_party_office", index=False)
# writer.save()
